# %%
import zipfile
import os
import pandas as pd
import requests
import deflatebr as dbr
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import sidrapy

# %%
def concatenar_csvs(diretorio):
    frames = []

    for arquivo in os.listdir(diretorio):
        if arquivo.endswith('.csv'):
            caminho_arquivo = os.path.join(diretorio, arquivo)
            
            df = pd.read_csv(caminho_arquivo, encoding='utf-8', delimiter=";", decimal=",")
            df = df.rename(columns={df.columns[0]: "data_base"})
            df = df.rename(columns={df.columns[6]: "cnae_secao"})
            df = df[df['cliente'] == "PJ"]
            df['cnae_secao']=df['cnae_secao'].str.replace('PJ - ','')
            df = df.iloc[:, [0, 6, 20, 22]]
            df['data_base'] = pd.to_datetime(df['data_base'], format="%Y-%m-%d")
            df['mes'] = df['data_base'].dt.month
            df = df[df['mes'] == 12]
            
            frames.append(df)

    df_concatenado = pd.concat(frames, ignore_index=True)

    return df_concatenado

# %%
anos = list(range(2012, 2024))
dataframes = []

for ano in anos:
    diretorio = f"planilha_{ano}"
    dataframe_ano = concatenar_csvs(diretorio)
    dataframes.append(dataframe_ano)

df_total = pd.concat(dataframes, ignore_index=False)

# %%
df_total.head(5)
# Out:
#    data_base                                         cnae_secao  \
# 0 2012-12-31  Administração pública, defesa e seguridade social
# 1 2012-12-31  Administração pública, defesa e seguridade social
# 2 2012-12-31  Administração pública, defesa e seguridade social
# 3 2012-12-31  Administração pública, defesa e seguridade social
# 4 2012-12-31  Administração pública, defesa e seguridade social
#
#    carteira_ativa  ativo_problematico  mes
# 0    9.665000e+01               96.65   12
# 1    1.906800e+02              190.68   12
# 2    3.351102e+04                0.00   12
# 3    1.034660e+03                0.00   12
# 4    1.830211e+09                0.00   12

# %%
df_total_group = df_total.groupby(['data_base', 'cnae_secao'])[['carteira_ativa', 'ativo_problematico']].sum().reset_index()

# %%
df_total_group['data_base'] = df_total_group['data_base'].dt.strftime('%Y') #Converti apenas para o ano porque as séries que vou usar do ibge são anuais

# %%
df_total_group.head(5)
# Out:
#   data_base                                         cnae_secao  \
# 0      2012  Administração pública, defesa e seguridade social
# 1      2012  Agricultura, pecuária, produção florestal, pes...
# 2      2012                           Alojamento e alimentação
# 3      2012                Artes, cultura, esporte e recreação
# 4      2012  Atividades administrativas e serviços compleme...
#
#    carteira_ativa  ativo_problematico
# 0    4.773897e+10        1.342493e+07
# 1    1.891586e+10        1.105283e+09
# 2    1.222610e+10        1.141509e+09
# 3    3.389071e+09        1.838335e+08
# 4    3.591193e+10        3.006880e+09

# %%
#Extraindo informações do IBGE via api

empresas = sidrapy.table.get_table(
    table_code="2718",
    territorial_level="1",
    ibge_territorial_code="all",
    period="last 9",
    variable="630",
    classifications={"12762": "all", "370": "9504", "369": "all"},
    
)

empresas.columns = empresas.iloc[0] #troca a primeira linha para o nome da coluna
empresas = empresas.iloc[1:, :]

# %%
empresas = empresas.drop(columns = ['Nível Territorial', 'Unidade de Medida', 'Nível Territorial (Código)', 'Unidade de Medida (Código)',
                                    'Brasil (Código)', 'Brasil', 'Variável (Código)', 
                                    'Classificação Nacional de Atividades Econômicas (CNAE 2.0) (Código)',
                                    'Faixas de pessoal ocupado assalariado (Código)',
                                    'Faixas de pessoal ocupado assalariado',
                                    'Tipo de evento da empresa (Código)',
                                    'Ano (Código)',
                                   'Variável'])

# %%
empresas = empresas.rename(columns={"Classificação Nacional de Atividades Econômicas (CNAE 2.0)": "cnae_secao",
                                     "Tipo de evento da empresa": "evento",
                                    "Valor": "qtde_empresas"})

# %%
empresas['qtde_empresas'] = empresas['qtde_empresas'].replace("-", np.nan)

# %%
empresas['qtde_empresas'] = empresas['qtde_empresas'].astype("float")

# %%
empresas_pivot = empresas.pivot_table(index=['Ano', 'cnae_secao'], 
                                      columns='evento', 
                                      values='qtde_empresas').reset_index()

# %%
empresas_pivot['cnae_secao'] = empresas_pivot['cnae_secao'].str.slice(start=2)

# %%
empresas_pivot.head(3)
# Out:
# evento   Ano                                         cnae_secao  Entrada  \
# 0       2013  Agricultura, pecuária, produção florestal, pes...   6706.0
# 1       2013                              Indústrias extrativas   2105.0
# 2       2013                        Indústrias de transformação  64665.0
#
# evento  Nascimento  Reentrada  Saída de atividade  Sobrevivente  \
# 0           4745.0     1961.0              5450.0       26487.0
# 1           1393.0      712.0              1545.0        9105.0
# 2          46261.0    18404.0             55564.0      381766.0
#
# evento  Total de empresas ativas
# 0                        33193.0
# 1                        11210.0
# 2                       446431.0

# %%
df_total_group.head(3)
# Out:
#   data_base                                         cnae_secao  \
# 0      2012  Administração pública, defesa e seguridade social
# 1      2012  Agricultura, pecuária, produção florestal, pes...
# 2      2012                           Alojamento e alimentação
#
#    carteira_ativa  ativo_problematico
# 0    4.773897e+10        1.342493e+07
# 1    1.891586e+10        1.105283e+09
# 2    1.222610e+10        1.141509e+09

# %%
df_corr_ibge_scr_pj = pd.merge(empresas_pivot,
                               df_total_group,
                               left_on = ["Ano", "cnae_secao"],
                               right_on = ["data_base", "cnae_secao"])

# %%
df_corr_ibge_scr_pj[df_corr_ibge_scr_pj['cnae_secao'] == "Indústrias extrativas"]
# Out:
#       Ano             cnae_secao  Entrada  Nascimento  Reentrada  \
# 0    2013  Indústrias extrativas   2105.0      1393.0      712.0
# 19   2014  Indústrias extrativas   1471.0      1004.0      467.0
# 38   2015  Indústrias extrativas   1510.0       947.0      563.0
# 57   2016  Indústrias extrativas   1332.0       781.0      551.0
# 75   2017  Indústrias extrativas   1315.0       859.0      456.0
# 93   2018  Indústrias extrativas   1301.0       866.0      435.0
# 112  2019  Indústrias extrativas   2171.0      1476.0      695.0
# 131  2020  Indústrias extrativas   1326.0       950.0      376.0
# 149  2021  Indústrias extrativas   1715.0      1302.0      413.0
#
#      Saída de atividade  Sobrevivente  Total de empresas ativas data_base  \
# 0                1545.0        9105.0                   11210.0      2013
# 19               2058.0        9138.0                   10609.0      2014
# 38               1623.0        8962.0                   10472.0      2015
# 57               1510.0        8963.0                   10295.0      2016
# 75               1510.0        8752.0                   10067.0      2017
# 93               1657.0        8425.0                    9726.0      2018
# 112              1162.0        8567.0                   10738.0      2019
# 131              1261.0        9563.0                   10889.0      2020
# 149              1053.0        9792.0                   11507.0      2021
#
#      carteira_ativa  ativo_problematico
# 0      2.984883e+10        2.680275e+08
# 19     3.398217e+10        4.590628e+08
# 38     4.323098e+10        4.704223e+08
# 57     3.298762e+10        1.571414e+09
# 75     2.256922e+10        6.730031e+08
# 93     1.772448e+10        4.456610e+08
# 112    1.464031e+10        2.514662e+08
# 131    1.625110e+10        4.703231e+08
# 149    1.415300e+10        1.625135e+09

# %%
df_corr_ibge_scr_pj_num = df_corr_ibge_scr_pj.drop(columns = {'Ano',
                                                              'cnae_secao',
                                                             'data_base'}, axis=1)

# %%
sns.set_theme(style="white")

corr = df_corr_ibge_scr_pj_num.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Draw the heatmap with the mask and correct aspect ratio
sns_heatmap = sns.heatmap(corr, mask=mask, cmap="Spectral", #possíveis parâmetros para o cmap: https://matplotlib.org/stable/users/explain/colors/colormaps.html
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot = True)

# %%
df_scatter_plot = df_corr_ibge_scr_pj.drop(columns = ['Ano'], axis=1)

# %%
import warnings
warnings.filterwarnings('ignore')

palette = sns.color_palette("tab20", 19) #possíveis palettes

sns.scatterplot(data = df_scatter_plot, x="ativo_problematico", y="Saída de atividade", hue = "cnae_secao", palette=palette)
plt.legend(title='cnae_secao', loc='lower center', bbox_to_anchor=(0.5, -0.7), ncol=3)
plt.tight_layout()
plt.show()

# %%
df_scatter_plot.to_csv("df_corr_ibge_scr_pj.csv", index=False)
