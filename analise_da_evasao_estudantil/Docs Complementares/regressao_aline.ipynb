# %%
import pandas as pd
from folium.plugins import HeatMap
import folium
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
import os 
filepath = os.path.join(os.getcwd(), 'dataset_tratado2.csv')

# %%
import chardet
with open("dataset_tratado2.csv", 'rb') as rawdata:
    result = chardet.detect(rawdata.read(10000))

# %%
result
# Out:
# {'encoding': 'UTF-8-SIG', 'confidence': 1.0, 'language': ''}

# %%
df_completo = pd.read_csv(filepath, engine='python', 
                     on_bad_lines='warn', encoding = "UTF-8-SIG", header=0, sep = ";")

# %%
df_completo.keys()
# Out:
# Index(['ANO_INGRESSO', 'SEMESTRE_INGRESSO', 'TIPO_INGRESSO', 'COTA',
#        'CURSO_NOME', 'AREA', 'SITUACAO', 'MOTIVO_SAIDA', 'CAMPUS', 'TURNO',
#        'ETNIA', 'SEXO', 'TIPOCURSO', 'LNG', 'LAT', 'LOCAL', 'LNG_ORGM',
#        'LAT_ORGM', 'LOCAL_ORGM', 'RENDA BAIXA', 'ESCOLA PÚBLICA', 'ETNIA PPI',
#        'PCD', 'ESTADO'],
#       dtype='object')

# %%
df_completo.head(10)
# Out:
#    ANO_INGRESSO  SEMESTRE_INGRESSO                     TIPO_INGRESSO     COTA  \
# 0          2008                  1       Transfer√™ncia Obrigat√≥ria      NaN
# 1          2008                  1                        VESTIBULAR  Grupo B
# 2          2008                  1                              PISM  Grupo C
# 3          2008                  1                        VESTIBULAR  Grupo C
# 4          2008                  1                        VESTIBULAR  Grupo B
# 5          2008                  1  CV/Nova Modalidade/Habilita√ß√£o      NaN
# 6          2008                  1                              PISM  Grupo C
# 7          2008                  1                        VESTIBULAR  Grupo B
# 8          2008                  1                              PISM  Grupo C
# 9          2008                  1                        VESTIBULAR  Grupo C
#
#               CURSO_NOME                   AREA   SITUACAO  \
# 0  CI√äNCIAS BIOL√ìGICAS  Ci√™ncias Biol√≥gicas    Evadido
# 1  CI√äNCIAS BIOL√ìGICAS  Ci√™ncias Biol√≥gicas    Evadido
# 2  CI√äNCIAS BIOL√ìGICAS  Ci√™ncias Biol√≥gicas    Evadido
# 3  CI√äNCIAS BIOL√ìGICAS  Ci√™ncias Biol√≥gicas  Concluido
# 4  CI√äNCIAS BIOL√ìGICAS  Ci√™ncias Biol√≥gicas    Evadido
# 5  CI√äNCIAS BIOL√ìGICAS  Ci√™ncias Biol√≥gicas    Evadido
# 6  CI√äNCIAS BIOL√ìGICAS  Ci√™ncias Biol√≥gicas    Evadido
# 7  CI√äNCIAS BIOL√ìGICAS  Ci√™ncias Biol√≥gicas    Evadido
# 8  CI√äNCIAS BIOL√ìGICAS  Ci√™ncias Biol√≥gicas    Evadido
# 9  CI√äNCIAS BIOL√ìGICAS  Ci√™ncias Biol√≥gicas    Evadido
#
#            MOTIVO_SAIDA        CAMPUS     TURNO  ...        LAT  \
# 0         A Especificar  JUIZ DE FORA  INTEGRAL  ... -21.753129
# 1         A Especificar  JUIZ DE FORA  INTEGRAL  ... -21.804313
# 2              Abandono  JUIZ DE FORA  INTEGRAL  ... -21.750069
# 3            Conclus√£o  JUIZ DE FORA  INTEGRAL  ... -21.718564
# 4         A Especificar  JUIZ DE FORA  INTEGRAL  ... -20.850899
# 5  Abandono/2¬™ Mod/Hab  JUIZ DE FORA  INTEGRAL  ... -21.762424
# 6     Mudan√ßa de Curso  JUIZ DE FORA  INTEGRAL  ... -25.424429
# 7         A Especificar  JUIZ DE FORA  INTEGRAL  ... -20.754870
# 8         A Especificar  JUIZ DE FORA  INTEGRAL  ... -21.745732
# 9         A Especificar  JUIZ DE FORA  INTEGRAL  ... -21.762424
#
#                                               LOCAL LNG_ORGM  LAT_ORGM  \
# 0             VALE DO IPE, JUIZ DE FORA, MG, BRASIL      NaN       NaN
# 1  PARQUE JARDIM DA SERRA, JUIZ DE FORA, MG, BRASIL      NaN       NaN
# 2          SANTA CATARINA, JUIZ DE FORA, MG, BRASIL      NaN       NaN
# 3                           ANDRELANDIA, MG, BRASIL      NaN       NaN
# 4                         PAULA CANDIDO, MG, BRASIL      NaN       NaN
# 5                  CENTRO, JUIZ DE FORA, MG, BRASIL      NaN       NaN
# 6                              CURITIBA, PR, BRASIL      NaN       NaN
# 7                                VICOSA, MG, BRASIL      NaN       NaN
# 8        MARIANO PROCOPIO, JUIZ DE FORA, MG, BRASIL      NaN       NaN
# 9                  CENTRO, JUIZ DE FORA, MG, BRASIL      NaN       NaN
#
#    LOCAL_ORGM RENDA BAIXA  ESCOLA PÚBLICA  ETNIA PPI   PCD ESTADO
# 0         NaN        N√£o            N√£o       N√£o  N√£o    NaN
# 1         NaN         Sim             Sim       N√£o  N√£o    NaN
# 2         NaN        N√£o            N√£o       N√£o  N√£o    NaN
# 3         NaN        N√£o            N√£o       N√£o  N√£o    NaN
# 4         NaN         Sim             Sim       N√£o  N√£o    NaN
# 5         NaN        N√£o            N√£o       N√£o  N√£o    NaN
# 6         NaN        N√£o            N√£o       N√£o  N√£o    NaN
# 7         NaN         Sim             Sim       N√£o  N√£o    NaN
# 8         NaN        N√£o            N√£o       N√£o  N√£o    NaN
# 9         NaN        N√£o            N√£o       N√£o  N√£o    NaN
#
# [10 rows x 24 columns]
