# %% [markdown]
# # Mapeamento de patentes

# %% [markdown]
# ## Bibliotecas

# %%
from bs4 import BeautifulSoup
import pandas as pd
import os
import requests
import zipfile
import time

# %% [markdown]
# ## Download das revistas em zip (com tratamento de exceção)

# %% [markdown]
# Fonte de dados: http://revistas.inpi.gov.br/rpi/#

# %%
#Funcao para verificar se o arquivo zip ja foi baixado anteriormente.
def download_zip(zip_url, output_folder):
    # Nome do arquivo na pasta
    file_name = os.path.basename(zip_url)

    # Caminho completo para o arquivo ZIP
    zip_path = os.path.join(output_folder, file_name)

    # Verifique se o arquivo já existe na pasta
    if os.path.exists(zip_path):
        print(f"Arquivo ZIP '{file_name}' já existe na pasta, pulando o download.")
        return

    # Download do arquivo ZIP diretamente na pasta de saída + TRATAMENTO DE EXCEÇÃO
    max_retries = 3  # Número máximo de tentativas
    for retry in range(max_retries):
        try:
            response = requests.get(zip_url)
            response.raise_for_status()  # Lançar exceção se a resposta não for bem-sucedida

            with open(zip_path, "wb") as zip_file:
                zip_file.write(response.content)

            print(f"Arquivo ZIP salvo em '{zip_path}'")
            break  # Download bem-sucedido, saia do loop de tentativas
        except requests.exceptions.RequestException as e:
            if retry < max_retries - 1:
                if isinstance(e, requests.exceptions.HTTPError) and e.response.status_code == 404:
                    print("Erro: Arquivo não encontrado.")
                    break  # Não é necessário tentar novamente se o arquivo não existe
                else:
                    print(f"Erro ao baixar o arquivo ZIP '{file_name}': {e}")
                    time.sleep(5)  # Aguarde 5 segundos antes de tentar novamente
            else:
                print(f"Erro ao baixar o arquivo ZIP '{file_name}': {e}")
                break

url2 = 2557
while url2 <= 2660:
    zip_url = 'http://revistas.inpi.gov.br/txt/P' + str(url2) + '.zip'
    # Pasta onde você deseja salvar o arquivo ZIP
    output_folder = 'dados_zip'

    # Verifique se a pasta de saída existe e a crie se não existir
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    download_zip(zip_url, output_folder)
    url2 += 1
# Out:
# Arquivo ZIP salvo em 'dados_zip\P2557.zip'
# Arquivo ZIP salvo em 'dados_zip\P2558.zip'
# Arquivo ZIP salvo em 'dados_zip\P2559.zip'
# Arquivo ZIP salvo em 'dados_zip\P2560.zip'
# Arquivo ZIP salvo em 'dados_zip\P2561.zip'
# Arquivo ZIP salvo em 'dados_zip\P2562.zip'
# Arquivo ZIP salvo em 'dados_zip\P2563.zip'
# Arquivo ZIP salvo em 'dados_zip\P2564.zip'
# Arquivo ZIP salvo em 'dados_zip\P2565.zip'
# Arquivo ZIP salvo em 'dados_zip\P2566.zip'
# Arquivo ZIP salvo em 'dados_zip\P2567.zip'
# Arquivo ZIP salvo em 'dados_zip\P2568.zip'
# Arquivo ZIP salvo em 'dados_zip\P2569.zip'
# Arquivo ZIP salvo em 'dados_zip\P2570.zip'
# Arquivo ZIP salvo em 'dados_zip\P2571.zip'
# Arquivo ZIP salvo em 'dados_zip\P2572.zip'
# Arquivo ZIP salvo em 'dados_zip\P2573.zip'
# Arquivo ZIP salvo em 'dados_zip\P2574.zip'
# Arquivo ZIP salvo em 'dados_zip\P2575.zip'
# Arquivo ZIP salvo em 'dados_zip\P2576.zip'
# Arquivo ZIP salvo em 'dados_zip\P2577.zip'
# Arquivo ZIP salvo em 'dados_zip\P2578.zip'
# Arquivo ZIP salvo em 'dados_zip\P2579.zip'
# Arquivo ZIP salvo em 'dados_zip\P2580.zip'
# Arquivo ZIP salvo em 'dados_zip\P2581.zip'
# Arquivo ZIP salvo em 'dados_zip\P2582.zip'
# Arquivo ZIP salvo em 'dados_zip\P2583.zip'
# Arquivo ZIP salvo em 'dados_zip\P2584.zip'
# Arquivo ZIP salvo em 'dados_zip\P2585.zip'
# Arquivo ZIP salvo em 'dados_zip\P2586.zip'
# Arquivo ZIP salvo em 'dados_zip\P2587.zip'
# Arquivo ZIP salvo em 'dados_zip\P2588.zip'
# Arquivo ZIP salvo em 'dados_zip\P2589.zip'
# Arquivo ZIP salvo em 'dados_zip\P2590.zip'
# Arquivo ZIP salvo em 'dados_zip\P2591.zip'
# Arquivo ZIP salvo em 'dados_zip\P2592.zip'
# Arquivo ZIP salvo em 'dados_zip\P2593.zip'
# Arquivo ZIP salvo em 'dados_zip\P2594.zip'
# Arquivo ZIP salvo em 'dados_zip\P2595.zip'
# Arquivo ZIP salvo em 'dados_zip\P2596.zip'
# Arquivo ZIP salvo em 'dados_zip\P2597.zip'
# Arquivo ZIP salvo em 'dados_zip\P2598.zip'
# Arquivo ZIP salvo em 'dados_zip\P2599.zip'
# Arquivo ZIP salvo em 'dados_zip\P2600.zip'
# Arquivo ZIP salvo em 'dados_zip\P2601.zip'
# Arquivo ZIP salvo em 'dados_zip\P2602.zip'
# Arquivo ZIP salvo em 'dados_zip\P2603.zip'
# Arquivo ZIP salvo em 'dados_zip\P2604.zip'
# Arquivo ZIP salvo em 'dados_zip\P2605.zip'
# Arquivo ZIP salvo em 'dados_zip\P2606.zip'
# Arquivo ZIP salvo em 'dados_zip\P2607.zip'
# Arquivo ZIP salvo em 'dados_zip\P2608.zip'
# Arquivo ZIP salvo em 'dados_zip\P2609.zip'
# Arquivo ZIP salvo em 'dados_zip\P2610.zip'
# Arquivo ZIP salvo em 'dados_zip\P2611.zip'
# Arquivo ZIP salvo em 'dados_zip\P2612.zip'
# Arquivo ZIP salvo em 'dados_zip\P2613.zip'
# Arquivo ZIP salvo em 'dados_zip\P2614.zip'
# Arquivo ZIP salvo em 'dados_zip\P2615.zip'
# Arquivo ZIP salvo em 'dados_zip\P2616.zip'
# Arquivo ZIP salvo em 'dados_zip\P2617.zip'
# Arquivo ZIP salvo em 'dados_zip\P2618.zip'
# Arquivo ZIP salvo em 'dados_zip\P2619.zip'
# Arquivo ZIP salvo em 'dados_zip\P2620.zip'
# Arquivo ZIP salvo em 'dados_zip\P2621.zip'
# Arquivo ZIP salvo em 'dados_zip\P2622.zip'
# Arquivo ZIP salvo em 'dados_zip\P2623.zip'
# Arquivo ZIP salvo em 'dados_zip\P2624.zip'
# Arquivo ZIP salvo em 'dados_zip\P2625.zip'
# Arquivo ZIP salvo em 'dados_zip\P2626.zip'
# Arquivo ZIP salvo em 'dados_zip\P2627.zip'
# Arquivo ZIP salvo em 'dados_zip\P2628.zip'
# Arquivo ZIP salvo em 'dados_zip\P2629.zip'
# Arquivo ZIP salvo em 'dados_zip\P2630.zip'
# Arquivo ZIP salvo em 'dados_zip\P2631.zip'
# Arquivo ZIP salvo em 'dados_zip\P2632.zip'
# Arquivo ZIP salvo em 'dados_zip\P2633.zip'
# Arquivo ZIP salvo em 'dados_zip\P2634.zip'
# Arquivo ZIP salvo em 'dados_zip\P2635.zip'
# Arquivo ZIP salvo em 'dados_zip\P2636.zip'
# Arquivo ZIP salvo em 'dados_zip\P2637.zip'
# Arquivo ZIP salvo em 'dados_zip\P2638.zip'
# Arquivo ZIP salvo em 'dados_zip\P2639.zip'
# Arquivo ZIP salvo em 'dados_zip\P2640.zip'
# Arquivo ZIP salvo em 'dados_zip\P2641.zip'
# Arquivo ZIP salvo em 'dados_zip\P2642.zip'
# Arquivo ZIP salvo em 'dados_zip\P2643.zip'
# Arquivo ZIP salvo em 'dados_zip\P2644.zip'
# Arquivo ZIP salvo em 'dados_zip\P2645.zip'
# Arquivo ZIP salvo em 'dados_zip\P2646.zip'
# Arquivo ZIP salvo em 'dados_zip\P2647.zip'
# Arquivo ZIP salvo em 'dados_zip\P2648.zip'
# Arquivo ZIP salvo em 'dados_zip\P2649.zip'
# Arquivo ZIP salvo em 'dados_zip\P2650.zip'
# Arquivo ZIP salvo em 'dados_zip\P2651.zip'
# Arquivo ZIP salvo em 'dados_zip\P2652.zip'
# Arquivo ZIP salvo em 'dados_zip\P2653.zip'
# Arquivo ZIP salvo em 'dados_zip\P2654.zip'
# Arquivo ZIP salvo em 'dados_zip\P2655.zip'
# Arquivo ZIP salvo em 'dados_zip\P2656.zip'
# Arquivo ZIP salvo em 'dados_zip\P2657.zip'
# Arquivo ZIP salvo em 'dados_zip\P2658.zip'
# Arquivo ZIP salvo em 'dados_zip\P2659.zip'
# Arquivo ZIP salvo em 'dados_zip\P2660.zip'

# %% [markdown]
# ## Descompactar e organizar os arquivos

# %%
def extract_zip_files(output_folder):
    # Certifique-se de que a pasta de saída existe
    if not os.path.exists(output_folder):
        print(f"A pasta de saída '{output_folder}' não existe.")
        return

    # Pasta onde você deseja salvar os arquivos XML extraídos
    xml_folder = 'dados_xml'

    # Verifique se a pasta de saída para os XML existe e a crie se não existir
    if not os.path.exists(xml_folder):
        os.makedirs(xml_folder)

    # Percorre todos os arquivos na pasta de saída
    for root, dirs, files in os.walk(output_folder):
        for file in files:
            if file.lower().endswith(".zip"):
                zip_path = os.path.join(root, file)

                try:
                    # Abra o arquivo ZIP
                    with zipfile.ZipFile(zip_path, "r") as zipf:
                        for filename in zipf.namelist():
                            if filename.startswith("Patente_"):
                                # Extraia o arquivo XML correspondente
                                with zipf.open(filename) as xml_file:
                                    xml_content = xml_file.read()
                                    xml_filename = os.path.join(xml_folder, filename)
                                    with open(xml_filename, "wb") as output_file:
                                        output_file.write(xml_content)

                                # Move o arquivo XML extraído com sucesso para a pasta 'dados_xml'
                                os.rename(xml_filename, os.path.join(xml_folder, filename))
                                print(f"Arquivo XML {filename} extraído com sucesso em '{xml_filename}' e movido para '{xml_folder}'")
                except zipfile.BadZipFile:
                    print(f"Erro ao extrair o arquivo ZIP '{file}': Arquivo ZIP inválido.")
                except Exception as e:
                    print(f"Erro ao processar o arquivo ZIP '{file}': {e}")

# Exemplo de uso
extract_zip_files('dados_zip')
# Out:
# Arquivo XML Patente_2557_07012020.xml extraído com sucesso em 'dados_xml\Patente_2557_07012020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2558_14012020.xml extraído com sucesso em 'dados_xml\Patente_2558_14012020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2559_21012020.xml extraído com sucesso em 'dados_xml\Patente_2559_21012020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2560_28012020.xml extraído com sucesso em 'dados_xml\Patente_2560_28012020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2561_04022020.xml extraído com sucesso em 'dados_xml\Patente_2561_04022020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2562_11022020.xml extraído com sucesso em 'dados_xml\Patente_2562_11022020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2563_18022020.xml extraído com sucesso em 'dados_xml\Patente_2563_18022020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2564_27022020.xml extraído com sucesso em 'dados_xml\Patente_2564_27022020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2565_03032020.xml extraído com sucesso em 'dados_xml\Patente_2565_03032020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2566_10032020.xml extraído com sucesso em 'dados_xml\Patente_2566_10032020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2567_17032020.xml extraído com sucesso em 'dados_xml\Patente_2567_17032020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2568_24032020.xml extraído com sucesso em 'dados_xml\Patente_2568_24032020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2569_31032020.xml extraído com sucesso em 'dados_xml\Patente_2569_31032020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2570_07042020.xml extraído com sucesso em 'dados_xml\Patente_2570_07042020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2571_14042020.xml extraído com sucesso em 'dados_xml\Patente_2571_14042020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2572_22042020.xml extraído com sucesso em 'dados_xml\Patente_2572_22042020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2573_28042020.xml extraído com sucesso em 'dados_xml\Patente_2573_28042020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2574_05052020.xml extraído com sucesso em 'dados_xml\Patente_2574_05052020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2575_12052020.xml extraído com sucesso em 'dados_xml\Patente_2575_12052020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2576_19052020.xml extraído com sucesso em 'dados_xml\Patente_2576_19052020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2577_26052020.xml extraído com sucesso em 'dados_xml\Patente_2577_26052020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2578_02062020.xml extraído com sucesso em 'dados_xml\Patente_2578_02062020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2579_09062020.xml extraído com sucesso em 'dados_xml\Patente_2579_09062020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2580_16062020.xml extraído com sucesso em 'dados_xml\Patente_2580_16062020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2581_23062020.xml extraído com sucesso em 'dados_xml\Patente_2581_23062020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2582_30062020.xml extraído com sucesso em 'dados_xml\Patente_2582_30062020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2583_07072020.xml extraído com sucesso em 'dados_xml\Patente_2583_07072020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2584_14072020.xml extraído com sucesso em 'dados_xml\Patente_2584_14072020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2585_21072020.xml extraído com sucesso em 'dados_xml\Patente_2585_21072020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2586_28072020.xml extraído com sucesso em 'dados_xml\Patente_2586_28072020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2587_04082020.xml extraído com sucesso em 'dados_xml\Patente_2587_04082020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2588_11082020.xml extraído com sucesso em 'dados_xml\Patente_2588_11082020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2589_18082020.xml extraído com sucesso em 'dados_xml\Patente_2589_18082020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2590_25082020.xml extraído com sucesso em 'dados_xml\Patente_2590_25082020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2591_01092020.xml extraído com sucesso em 'dados_xml\Patente_2591_01092020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2592_08092020.xml extraído com sucesso em 'dados_xml\Patente_2592_08092020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2593_15092020.xml extraído com sucesso em 'dados_xml\Patente_2593_15092020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2594_24092020.xml extraído com sucesso em 'dados_xml\Patente_2594_24092020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2595_29092020.xml extraído com sucesso em 'dados_xml\Patente_2595_29092020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2596_06102020.xml extraído com sucesso em 'dados_xml\Patente_2596_06102020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2597_13102020.xml extraído com sucesso em 'dados_xml\Patente_2597_13102020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2598_20102020.xml extraído com sucesso em 'dados_xml\Patente_2598_20102020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2599_27102020.xml extraído com sucesso em 'dados_xml\Patente_2599_27102020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2600_03112020.xml extraído com sucesso em 'dados_xml\Patente_2600_03112020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2601_10112020.xml extraído com sucesso em 'dados_xml\Patente_2601_10112020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2602_17112020.xml extraído com sucesso em 'dados_xml\Patente_2602_17112020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2603_24112020.xml extraído com sucesso em 'dados_xml\Patente_2603_24112020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2604_01122020.xml extraído com sucesso em 'dados_xml\Patente_2604_01122020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2605_08122020.xml extraído com sucesso em 'dados_xml\Patente_2605_08122020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2606_15122020.xml extraído com sucesso em 'dados_xml\Patente_2606_15122020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2607_22122020.xml extraído com sucesso em 'dados_xml\Patente_2607_22122020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2608_29122020.xml extraído com sucesso em 'dados_xml\Patente_2608_29122020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2609_05012021.xml extraído com sucesso em 'dados_xml\Patente_2609_05012021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2610_12012021.xml extraído com sucesso em 'dados_xml\Patente_2610_12012021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2611_19012021.xml extraído com sucesso em 'dados_xml\Patente_2611_19012021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2612_26012021.xml extraído com sucesso em 'dados_xml\Patente_2612_26012021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2613_02022021.xml extraído com sucesso em 'dados_xml\Patente_2613_02022021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2614_09022021.xml extraído com sucesso em 'dados_xml\Patente_2614_09022021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2615_17022021.xml extraído com sucesso em 'dados_xml\Patente_2615_17022021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2616_23022021.xml extraído com sucesso em 'dados_xml\Patente_2616_23022021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2617_02032021.xml extraído com sucesso em 'dados_xml\Patente_2617_02032021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2618_09032021.xml extraído com sucesso em 'dados_xml\Patente_2618_09032021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2619_16032021.xml extraído com sucesso em 'dados_xml\Patente_2619_16032021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2620_23032021.xml extraído com sucesso em 'dados_xml\Patente_2620_23032021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2621_30032021.xml extraído com sucesso em 'dados_xml\Patente_2621_30032021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2622_06042021.xml extraído com sucesso em 'dados_xml\Patente_2622_06042021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2623_13042021.xml extraído com sucesso em 'dados_xml\Patente_2623_13042021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2624_20042021.xml extraído com sucesso em 'dados_xml\Patente_2624_20042021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2625_27042021.xml extraído com sucesso em 'dados_xml\Patente_2625_27042021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2626_04052021.xml extraído com sucesso em 'dados_xml\Patente_2626_04052021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2627_11052021.xml extraído com sucesso em 'dados_xml\Patente_2627_11052021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2628_18052021.xml extraído com sucesso em 'dados_xml\Patente_2628_18052021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2629_25052021.xml extraído com sucesso em 'dados_xml\Patente_2629_25052021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2630_01062021.xml extraído com sucesso em 'dados_xml\Patente_2630_01062021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2631_08062021.xml extraído com sucesso em 'dados_xml\Patente_2631_08062021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2632_15062021.xml extraído com sucesso em 'dados_xml\Patente_2632_15062021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2633_22062021.xml extraído com sucesso em 'dados_xml\Patente_2633_22062021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2634_29062021.xml extraído com sucesso em 'dados_xml\Patente_2634_29062021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2635_06072021.xml extraído com sucesso em 'dados_xml\Patente_2635_06072021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2636_13072021.xml extraído com sucesso em 'dados_xml\Patente_2636_13072021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2637_20072021.xml extraído com sucesso em 'dados_xml\Patente_2637_20072021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2638_27072021.xml extraído com sucesso em 'dados_xml\Patente_2638_27072021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2639_03082021.xml extraído com sucesso em 'dados_xml\Patente_2639_03082021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2640_10082021.xml extraído com sucesso em 'dados_xml\Patente_2640_10082021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2641_17082021.xml extraído com sucesso em 'dados_xml\Patente_2641_17082021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2642_24082021.xml extraído com sucesso em 'dados_xml\Patente_2642_24082021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2643_31082021.xml extraído com sucesso em 'dados_xml\Patente_2643_31082021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2644_08092021.xml extraído com sucesso em 'dados_xml\Patente_2644_08092021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2645_14092021.xml extraído com sucesso em 'dados_xml\Patente_2645_14092021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2646_21092021.xml extraído com sucesso em 'dados_xml\Patente_2646_21092021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2647_28092021.xml extraído com sucesso em 'dados_xml\Patente_2647_28092021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2648_05102021.xml extraído com sucesso em 'dados_xml\Patente_2648_05102021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2649_13102021.xml extraído com sucesso em 'dados_xml\Patente_2649_13102021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2650_19102021.xml extraído com sucesso em 'dados_xml\Patente_2650_19102021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2651_26102021.xml extraído com sucesso em 'dados_xml\Patente_2651_26102021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2652_03112021.xml extraído com sucesso em 'dados_xml\Patente_2652_03112021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2653_09112021.xml extraído com sucesso em 'dados_xml\Patente_2653_09112021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2654_16112021.xml extraído com sucesso em 'dados_xml\Patente_2654_16112021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2655_23112021.xml extraído com sucesso em 'dados_xml\Patente_2655_23112021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2656_30112021.xml extraído com sucesso em 'dados_xml\Patente_2656_30112021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2657_07122021.xml extraído com sucesso em 'dados_xml\Patente_2657_07122021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2658_14122021.xml extraído com sucesso em 'dados_xml\Patente_2658_14122021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2659_21122021.xml extraído com sucesso em 'dados_xml\Patente_2659_21122021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2660_28122021.xml extraído com sucesso em 'dados_xml\Patente_2660_28122021.xml' e movido para 'dados_xml'

# %% [markdown]
# ## Raspagem dos dados

# %%
# Definir função para raspagem de um arquivo xml
def raspagem(soup):
    # Inicializar listas para armazenar os dados
    data_publicacao = []
    diretoria = []
    numero_revista = []
    codigo = []
    titulo = []
    numero = []
    data_deposito = []
    data_prioridade = []
    cod_prioridade = []
    classificacoes_internacionais = []
    classificacoes_nacionais = []
    titulo_inid = []
    titular_nome = []
    titular_uf = []
    titular_pais = []
    inventor_nome = []

    # Extrair os dados do xml
    for despacho in soup.find_all(lambda tag: tag.name == 'despacho' and '<codigo>3.1</codigo>' in str(tag)):
        data_publ = soup.revista['dataPublicacao']
        diret = soup.revista['diretoria']
        num_rev = soup.revista['numero']
        cod = despacho.find('codigo').text
        tit = despacho.find('titulo').text
        num = despacho.find('numero').text
        data = despacho.find('data-deposito').text
        data_prio = despacho.find('data-prioridade', inid="31").text if despacho.find('data-prioridade', inid="31") else None
        cod_prio1 = despacho.find('sigla-pais', inid="33").text if despacho.find('sigla-pais', inid="33") else None
        cod_prio2 = despacho.find('numero-prioridade', inid="32").text if despacho.find('numero-prioridade', inid="32") else None
        cod_prio = cod_prio1 + cod_prio2 if (cod_prio1 != None and cod_prio2 != None) else None
        internacionais = '; '.join(ci.text for ci in despacho.find_all('classificacao-internacional'))
        nacionais = '; '.join(cn.text for cn in despacho.find_all('classificacao-nacional'))
        tit_inid = despacho.find('titulo', inid="54").text if despacho.find('titulo', inid="54") else None
        titu_nome = despacho.find('nome-completo').text if despacho.find('nome-completo') else None
        titu_uf = despacho.find('uf').text if despacho.find('uf') else None
        titu_pais = despacho.find('sigla').text if despacho.find('sigla') else None
        invent_nome = despacho.find('inventor').text if despacho.find('inventor') else None
        # Incluir os dados na lista
        data_publicacao.append(data_publ)
        diretoria.append(diret)
        numero_revista.append(num_rev)
        codigo.append(cod)
        titulo.append(tit)
        numero.append(num)
        data_deposito.append(data)
        data_prioridade.append(data_prio)
        cod_prioridade.append(cod_prio)
        classificacoes_internacionais.append(internacionais)
        classificacoes_nacionais.append(nacionais)
        titulo_inid.append(tit_inid)
        titular_nome.append(titu_nome)
        titular_uf.append(titu_uf)
        titular_pais.append(titu_pais)
        inventor_nome.append(invent_nome)
        # Transformar listas em dataframe
        df = pd.DataFrame({
            'data_publicacao' : data_publicacao,
            'diretoria' : diretoria,
            'numero_revista' : numero_revista,
            'codigo' : codigo,
            'titulo' : titulo,
            'numero' : numero,
            'data_deposito' : data_deposito,
            'data_prioridade' : data_prioridade,
            'cod_prioridade' : cod_prioridade,
            'classif_internacion' : classificacoes_nacionais,
            'classif_nacion' : classificacoes_nacionais,
            'titulo_inid' : titulo_inid,
            'titular_nome' : titular_nome,
            'titular_uf' : titular_uf,
            'titular_pais' : titular_pais,
            'inventor_nome' : inventor_nome
            })
    return(df)

# %% [markdown]
# ## Salvar dataframe completo

# %%
# !pip install tqdm --quiet
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from tqdm import tqdm

# %%
# Inicializar o dataframe
data = pd.DataFrame()

# Inicializar o timer
start_time = time.time()

# Lista de arquivos
arquivos = os.listdir('dados_xml')

# Inicializar a barra de progresso
with tqdm(total=len(arquivos), desc="Processando arquivos") as pbar:
    for file in arquivos:
        filepath = os.path.join('dados_xml', file)
        with open(filepath, encoding='utf-8') as arquivo_xml:
            conteudo = arquivo_xml.read()
        soup = BeautifulSoup(conteudo, 'xml')
        df = raspagem(soup)
        data = pd.concat([data, df], axis=0)
        pbar.update(1)

# Finalizar o timer
end_time = time.time()

# Calcular o tempo decorrido
tempo_decorrido = end_time - start_time

data.head(5)  # Verificar o dataframe

print(f"Tempo decorrido: {tempo_decorrido:.2f} segundos")
# Out:
# Processando arquivos: 100%|████████████████| 104/104 [1:00:27<00:00, 34.88s/it]
# Tempo decorrido: 3627.97 segundos

# %% [markdown]
# ### Verificar informações do dataframe completo

# %%
data.head(5)
# Out:
#   data_publicacao diretoria numero_revista codigo  \
# 0      07/01/2020   Patente           2557    3.1
# 1      07/01/2020   Patente           2557    3.1
# 2      07/01/2020   Patente           2557    3.1
# 3      07/01/2020   Patente           2557    3.1
# 4      07/01/2020   Patente           2557    3.1
#
#                                               titulo               numero  \
# 0  Publicação do Pedido de Patente ou de Certific...  BR 10 2013 016644-8
# 1  Publicação do Pedido de Patente ou de Certific...  BR 10 2014 001105-6
# 2  Publicação do Pedido de Patente ou de Certific...  BR 10 2017 004929-9
# 3  Publicação do Pedido de Patente ou de Certific...  BR 10 2017 024659-0
# 4  Publicação do Pedido de Patente ou de Certific...  BR 10 2017 026178-6
#
#   data_deposito data_prioridade cod_prioridade  \
# 0    27/06/2013            None           None
# 1    16/01/2014      18/01/2013    TW102201214
# 2    13/03/2017            None           None
# 3    17/11/2017            None           None
# 4    05/12/2017            None           None
#
#                        classif_internacion  \
# 0                   B29B 17/00; B29C 43/00
# 1                  F16C 11/04; E05F 1/1215
# 2                  H01Q 13/106; H01Q 1/241
# 3                     G01F 1/58; H04W 4/12
# 4  H04L 67/42; H04L 61/1558; H04L 29/12141
#
#                             classif_nacion  \
# 0                   B29B 17/00; B29C 43/00
# 1                  F16C 11/04; E05F 1/1215
# 2                  H01Q 13/106; H01Q 1/241
# 3                     G01F 1/58; H04W 4/12
# 4  H04L 67/42; H04L 61/1558; H04L 29/12141
#
#                                          titulo_inid  \
# 0  APERFEIÇOAMENTO INTRODUZIDO EM PROCESSO DE REC...
# 1        DOBRADIÇA PARA CONJUNTO DE CAPAS PROTETORAS
# 2  UMA NOVA ANTENA DE MICROFITA TRI-BANDA, DE TAM...
# 3  DISPOSITIVO DE MÚLTIPLOS MÓDULOS COM OTIMIZAÇÃ...
# 4  BEHAVIOR DEFINITION MODEL FOR INTERNET OF THIN...
#
#                         titular_nome titular_uf titular_pais  \
# 0            ACM EL ORRA COLCHÕES ME         SP           BR
# 1        KEYARROW (TAIWAN) CO., LTD.       None           TW
# 2      UNIVERSIDADE FEDERAL DO CEARÁ         CE           BR
# 3              CID GRANJA DOS SANTOS       None           BR
# 4  FUNDAÇÃO UNIVERSIDADE DO AMAZONAS         AM           BR
#
#                        inventor_nome
# 0     \nABDO CARIM MOUMTEZ EL ORRA\n
# 1                     \nFU-YI CHEN\n
# 2  \nANTONIO SERGIO BEZERRA SOMBRA\n
# 3          \nCID GRANJA DOS SANTOS\n
# 4    \nEDUARDO JAMES PEREIRA SOUTO\n

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14098 entries, 0 to 77
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   data_publicacao      14098 non-null  object
#  1   diretoria            14098 non-null  object
#  2   numero_revista       14098 non-null  object
#  3   codigo               14098 non-null  object
#  4   titulo               14098 non-null  object
#  5   numero               14098 non-null  object
#  6   data_deposito        14098 non-null  object
#  7   data_prioridade      3031 non-null   object
#  8   cod_prioridade       3031 non-null   object
#  9   classif_internacion  14098 non-null  object
#  10  classif_nacion       14098 non-null  object
#  11  titulo_inid          14098 non-null  object
#  12  titular_nome         14098 non-null  object
#  13  titular_uf           10921 non-null  object
#  14  titular_pais         14098 non-null  object
#  15  inventor_nome        14098 non-null  object
# dtypes: object(16)
# memory usage: 1.8+ MB

# %% [markdown]
# ## Tratamento dos dados

# %%
#Tratamento dos dados da coluna inventor_nome
data['inventor_nome'] = data['inventor_nome'].str.replace('\n', '') #Para tratar os dados da coluna inventor_nome

# %%
# Substituir todos os valores nulos por "NaN"
data_substituido = data.fillna("NaN")
print(data_substituido)
# Out:
#    data_publicacao diretoria numero_revista codigo  \
# 0       07/01/2020   Patente           2557    3.1
# 1       07/01/2020   Patente           2557    3.1
# 2       07/01/2020   Patente           2557    3.1
# 3       07/01/2020   Patente           2557    3.1
# 4       07/01/2020   Patente           2557    3.1
# ..             ...       ...            ...    ...
# 73      28/12/2021   Patente           2660    3.1
# 74      28/12/2021   Patente           2660    3.1
# 75      28/12/2021   Patente           2660    3.1
# 76      28/12/2021   Patente           2660    3.1
# 77      28/12/2021   Patente           2660    3.1
#
#                                                titulo               numero  \
# 0   Publicação do Pedido de Patente ou de Certific...  BR 10 2013 016644-8
# 1   Publicação do Pedido de Patente ou de Certific...  BR 10 2014 001105-6
# 2   Publicação do Pedido de Patente ou de Certific...  BR 10 2017 004929-9
# 3   Publicação do Pedido de Patente ou de Certific...  BR 10 2017 024659-0
# 4   Publicação do Pedido de Patente ou de Certific...  BR 10 2017 026178-6
# ..                                                ...                  ...
# 73  Publicação do Pedido de Patente ou de Certific...  BR 20 2020 012571-6
# 74  Publicação do Pedido de Patente ou de Certific...  BR 20 2020 012581-3
# 75  Publicação do Pedido de Patente ou de Certific...  BR 20 2020 012618-6
# 76  Publicação do Pedido de Patente ou de Certific...  BR 20 2020 012662-3
# 77  Publicação do Pedido de Patente ou de Certific...  BR 20 2020 026189-0
#
#    data_deposito data_prioridade    cod_prioridade  \
# 0     27/06/2013             NaN               NaN
# 1     16/01/2014      18/01/2013       TW102201214
# 2     13/03/2017             NaN               NaN
# 3     17/11/2017             NaN               NaN
# 4     05/12/2017             NaN               NaN
# ..           ...             ...               ...
# 73    19/06/2020             NaN               NaN
# 74    19/06/2020             NaN               NaN
# 75    19/06/2020             NaN               NaN
# 76    20/06/2020             NaN               NaN
# 77    21/12/2020      15/06/2020  CN202021116029.3
#
#                         classif_internacion  \
# 0                    B29B 17/00; B29C 43/00
# 1                   F16C 11/04; E05F 1/1215
# 2                   H01Q 13/106; H01Q 1/241
# 3                      G01F 1/58; H04W 4/12
# 4   H04L 67/42; H04L 61/1558; H04L 29/12141
# ..                                      ...
# 73                               B30B 15/14
# 74                    B62B 1/22; B62B 3/006
# 75                               A01D 34/86
# 76                     A61L 2/10; C12H 1/16
# 77
#
#                              classif_nacion  \
# 0                    B29B 17/00; B29C 43/00
# 1                   F16C 11/04; E05F 1/1215
# 2                   H01Q 13/106; H01Q 1/241
# 3                      G01F 1/58; H04W 4/12
# 4   H04L 67/42; H04L 61/1558; H04L 29/12141
# ..                                      ...
# 73                               B30B 15/14
# 74                    B62B 1/22; B62B 3/006
# 75                               A01D 34/86
# 76                     A61L 2/10; C12H 1/16
# 77
#
#                                           titulo_inid  \
# 0   APERFEIÇOAMENTO INTRODUZIDO EM PROCESSO DE REC...
# 1         DOBRADIÇA PARA CONJUNTO DE CAPAS PROTETORAS
# 2   UMA NOVA ANTENA DE MICROFITA TRI-BANDA, DE TAM...
# 3   DISPOSITIVO DE MÚLTIPLOS MÓDULOS COM OTIMIZAÇÃ...
# 4   BEHAVIOR DEFINITION MODEL FOR INTERNET OF THIN...
# ..                                                ...
# 73  SISTEMA COPIADOR PARA MÁQUINA DE PREPARAR E OU...
# 74        CONFIGURAÇÃO APLICADA EM CARRINHO PASSA FIO
# 75  APERFEIÇOAMENTO INTRODUZIDO EM SISTEMA ELETRÔNICO
# 76  DISPOSIÇÃO CONSTRUTIVA APLICADA EM CAIXA DE DE...
# 77                                            MÁSCARA
#
#                                   titular_nome titular_uf titular_pais  \
# 0                      ACM EL ORRA COLCHÕES ME         SP           BR
# 1                  KEYARROW (TAIWAN) CO., LTD.        NaN           TW
# 2                UNIVERSIDADE FEDERAL DO CEARÁ         CE           BR
# 3                        CID GRANJA DOS SANTOS        NaN           BR
# 4            FUNDAÇÃO UNIVERSIDADE DO AMAZONAS         AM           BR
# ..                                         ...        ...          ...
# 73                               HUGO PHILIPPE         SC           BR
# 74                         MOACYR FOPPA JUNIOR         SC           BR
# 75                MAGMAEL FERNANDES DOS SANTOS         PR           BR
# 76                        HUGO ABRAHÃO DE LIMA         RJ           BR
# 77  SHANDONG SHENGQUAN NEW MATERIALS CO., LTD.        NaN           CN
#
#                     inventor_nome
# 0      ABDO CARIM MOUMTEZ EL ORRA
# 1                      FU-YI CHEN
# 2   ANTONIO SERGIO BEZERRA SOMBRA
# 3           CID GRANJA DOS SANTOS
# 4     EDUARDO JAMES PEREIRA SOUTO
# ..                            ...
# 73                  HUGO PHILIPPE
# 74            MOACYR FOPPA JUNIOR
# 75   MAGMAEL FERNANDES DOS SANTOS
# 76           HUGO ABRAHÃO DE LIMA
# 77                   TANG, DIYUAN
#
# [14098 rows x 16 columns]

# %%
data_substituido.head(10)
# Out:
#   data_publicacao diretoria numero_revista codigo  \
# 0      07/01/2020   Patente           2557    3.1
# 1      07/01/2020   Patente           2557    3.1
# 2      07/01/2020   Patente           2557    3.1
# 3      07/01/2020   Patente           2557    3.1
# 4      07/01/2020   Patente           2557    3.1
# 5      07/01/2020   Patente           2557    3.1
# 6      07/01/2020   Patente           2557    3.1
# 7      07/01/2020   Patente           2557    3.1
# 8      07/01/2020   Patente           2557    3.1
# 9      07/01/2020   Patente           2557    3.1
#
#                                               titulo               numero  \
# 0  Publicação do Pedido de Patente ou de Certific...  BR 10 2013 016644-8
# 1  Publicação do Pedido de Patente ou de Certific...  BR 10 2014 001105-6
# 2  Publicação do Pedido de Patente ou de Certific...  BR 10 2017 004929-9
# 3  Publicação do Pedido de Patente ou de Certific...  BR 10 2017 024659-0
# 4  Publicação do Pedido de Patente ou de Certific...  BR 10 2017 026178-6
# 5  Publicação do Pedido de Patente ou de Certific...  BR 10 2017 027316-4
# 6  Publicação do Pedido de Patente ou de Certific...  BR 10 2018 001913-9
# 7  Publicação do Pedido de Patente ou de Certific...  BR 10 2018 009789-0
# 8  Publicação do Pedido de Patente ou de Certific...  BR 10 2018 009796-2
# 9  Publicação do Pedido de Patente ou de Certific...  BR 10 2018 011938-9
#
#   data_deposito data_prioridade cod_prioridade  \
# 0    27/06/2013             NaN            NaN
# 1    16/01/2014      18/01/2013    TW102201214
# 2    13/03/2017             NaN            NaN
# 3    17/11/2017             NaN            NaN
# 4    05/12/2017             NaN            NaN
# 5    06/12/2017             NaN            NaN
# 6    29/01/2018             NaN            NaN
# 7    15/05/2018             NaN            NaN
# 8    15/05/2018             NaN            NaN
# 9    13/06/2018             NaN            NaN
#
#                                  classif_internacion  \
# 0                             B29B 17/00; B29C 43/00
# 1                            F16C 11/04; E05F 1/1215
# 2                            H01Q 13/106; H01Q 1/241
# 3                               G01F 1/58; H04W 4/12
# 4            H04L 67/42; H04L 61/1558; H04L 29/12141
# 5  A23L 29/231; A23L 2/04; A23L 19/00; C08B 37/00...
# 6  C08G 18/4277; C08K 2003/0856; C08K 3/10; A43C ...
# 7  G06Q 30/00; G06F 3/04842; G06Q 10/08; G07C 9/0...
# 8
# 9                 H04M 1/20; H04B 1/3888; H04M 1/035
#
#                                       classif_nacion  \
# 0                             B29B 17/00; B29C 43/00
# 1                            F16C 11/04; E05F 1/1215
# 2                            H01Q 13/106; H01Q 1/241
# 3                               G01F 1/58; H04W 4/12
# 4            H04L 67/42; H04L 61/1558; H04L 29/12141
# 5  A23L 29/231; A23L 2/04; A23L 19/00; C08B 37/00...
# 6  C08G 18/4277; C08K 2003/0856; C08K 3/10; A43C ...
# 7  G06Q 30/00; G06F 3/04842; G06Q 10/08; G07C 9/0...
# 8
# 9                 H04M 1/20; H04B 1/3888; H04M 1/035
#
#                                          titulo_inid  \
# 0  APERFEIÇOAMENTO INTRODUZIDO EM PROCESSO DE REC...
# 1        DOBRADIÇA PARA CONJUNTO DE CAPAS PROTETORAS
# 2  UMA NOVA ANTENA DE MICROFITA TRI-BANDA, DE TAM...
# 3  DISPOSITIVO DE MÚLTIPLOS MÓDULOS COM OTIMIZAÇÃ...
# 4  BEHAVIOR DEFINITION MODEL FOR INTERNET OF THIN...
# 5  MÉTODO DE EXTRAÇÃO DA PECTINA ADAPTADA PARA SE...
# 6  COMPÓSITO INDUTÍVEL ELETROMAGNETICAMENTE CONTE...
# 7   MÁQUINA DE COMPARTILHAMENTO E ALUGUEL DE OBJETOS
# 8  DESENVOLVIMENTO DE PRODUTOS  FITOTERÁPICOS  AD...
# 9  ESTÚDIO PORTÁTIL COM ISOLAMENTO ACÚSTICO PARA ...
#
#                                         titular_nome titular_uf titular_pais  \
# 0                            ACM EL ORRA COLCHÕES ME         SP           BR
# 1                        KEYARROW (TAIWAN) CO., LTD.        NaN           TW
# 2                      UNIVERSIDADE FEDERAL DO CEARÁ         CE           BR
# 3                              CID GRANJA DOS SANTOS        NaN           BR
# 4                  FUNDAÇÃO UNIVERSIDADE DO AMAZONAS         AM           BR
# 5  MISSÃO SALESIANA DE MATO GROSSO UNIVERSIDADE C...         MS           BR
# 6                                      GRENDENE S.A.         CE           BR
# 7                                    RENTBRELLA S.A.         SP           BR
# 8   FUNDAÇÃO UNIVERSIDADE ESTADUAL DO CEARÁ - FUNECE         CE           BR
# 9                         MARCUS CEZAR KLAUTAU BONNA         SP           BR
#
#                                        inventor_nome
# 0                         ABDO CARIM MOUMTEZ EL ORRA
# 1                                         FU-YI CHEN
# 2                      ANTONIO SERGIO BEZERRA SOMBRA
# 3                              CID GRANJA DOS SANTOS
# 4                        EDUARDO JAMES PEREIRA SOUTO
# 5                              MARNEY PASCOLI CEREDA
# 6                           EDUARDO RADAELLI PASQUAL
# 7  Sigilo de Autor, conforme solicitado e com bas...
# 8                   JOSÉ CLAUDIO CARNEIRO DE FREITAS
# 9                         MARCUS CEZAR KLAUTAU BONNA

# %%
data_substituido.head(5)
# Out:
#   data_publicacao diretoria numero_revista codigo  \
# 0      2020-01-07   Patente           2557    3.1
# 1      2020-01-07   Patente           2557    3.1
# 2      2020-01-07   Patente           2557    3.1
# 3      2020-01-07   Patente           2557    3.1
# 4      2020-01-07   Patente           2557    3.1
#
#                                               titulo               numero  \
# 0  Publicação do Pedido de Patente ou de Certific...  BR 10 2013 016644-8
# 1  Publicação do Pedido de Patente ou de Certific...  BR 10 2014 001105-6
# 2  Publicação do Pedido de Patente ou de Certific...  BR 10 2017 004929-9
# 3  Publicação do Pedido de Patente ou de Certific...  BR 10 2017 024659-0
# 4  Publicação do Pedido de Patente ou de Certific...  BR 10 2017 026178-6
#
#   data_deposito data_prioridade cod_prioridade  \
# 0    2013-06-27             NaT            NaN
# 1    2014-01-16      2013-01-18    TW102201214
# 2    2017-03-13             NaT            NaN
# 3    2017-11-17             NaT            NaN
# 4    2017-12-05             NaT            NaN
#
#                        classif_internacion  \
# 0                   B29B 17/00; B29C 43/00
# 1                  F16C 11/04; E05F 1/1215
# 2                  H01Q 13/106; H01Q 1/241
# 3                     G01F 1/58; H04W 4/12
# 4  H04L 67/42; H04L 61/1558; H04L 29/12141
#
#                             classif_nacion  \
# 0                   B29B 17/00; B29C 43/00
# 1                  F16C 11/04; E05F 1/1215
# 2                  H01Q 13/106; H01Q 1/241
# 3                     G01F 1/58; H04W 4/12
# 4  H04L 67/42; H04L 61/1558; H04L 29/12141
#
#                                          titulo_inid  \
# 0  APERFEIÇOAMENTO INTRODUZIDO EM PROCESSO DE REC...
# 1        DOBRADIÇA PARA CONJUNTO DE CAPAS PROTETORAS
# 2  UMA NOVA ANTENA DE MICROFITA TRI-BANDA, DE TAM...
# 3  DISPOSITIVO DE MÚLTIPLOS MÓDULOS COM OTIMIZAÇÃ...
# 4  BEHAVIOR DEFINITION MODEL FOR INTERNET OF THIN...
#
#                         titular_nome titular_uf titular_pais  \
# 0            ACM EL ORRA COLCHÕES ME         SP           BR
# 1        KEYARROW (TAIWAN) CO., LTD.        NaN           TW
# 2      UNIVERSIDADE FEDERAL DO CEARÁ         CE           BR
# 3              CID GRANJA DOS SANTOS        NaN           BR
# 4  FUNDAÇÃO UNIVERSIDADE DO AMAZONAS         AM           BR
#
#                    inventor_nome
# 0     ABDO CARIM MOUMTEZ EL ORRA
# 1                     FU-YI CHEN
# 2  ANTONIO SERGIO BEZERRA SOMBRA
# 3          CID GRANJA DOS SANTOS
# 4    EDUARDO JAMES PEREIRA SOUTO

# %%
# Salvar o DataFrame em um arquivo CSV
data_substituido.to_csv('data_patentes.csv', index=False)

# %%
# Exporte o DataFrame para o arquivo Excel
data.to_excel('data_patentes_excel.xlsx', sheet_name='Planilha Patentes', index=False)
