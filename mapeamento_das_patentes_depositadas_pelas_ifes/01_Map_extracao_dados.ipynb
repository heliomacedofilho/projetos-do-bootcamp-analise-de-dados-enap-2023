# %% [markdown]
# # Mapeamento de patentes

# %% [markdown]
# ## Bibliotecas

# %%
import xml.etree.ElementTree as ET
from tqdm import tqdm
import pandas as pd
import os
import requests
import zipfile
import time

# %% [markdown]
# ## Download das revistas em zip (com tratamento de exceção)

# %% [markdown]
# Fonte de dados: http://revistas.inpi.gov.br/rpi/#

# %%
#Funcao para verificar se o arquivo zip ja foi baixado anteriormente.
def download_zip(zip_url, output_folder):
    # Nome do arquivo na pasta
    file_name = os.path.basename(zip_url)

    # Caminho completo para o arquivo ZIP
    zip_path = os.path.join(output_folder, file_name)

    # Verifique se o arquivo já existe na pasta
    if os.path.exists(zip_path):
        print(f"Arquivo ZIP '{file_name}' já existe na pasta, pulando o download.")
        return

    # Download do arquivo ZIP diretamente na pasta de saída + TRATAMENTO DE EXCEÇÃO
    max_retries = 3  # Número máximo de tentativas
    for retry in range(max_retries):
        try:
            response = requests.get(zip_url)
            response.raise_for_status()  # Lançar exceção se a resposta não for bem-sucedida

            with open(zip_path, "wb") as zip_file:
                zip_file.write(response.content)

            print(f"Arquivo ZIP salvo em '{zip_path}'")
            break  # Download bem-sucedido, saia do loop de tentativas
        except requests.exceptions.RequestException as e:
            if retry < max_retries - 1:
                if isinstance(e, requests.exceptions.HTTPError) and e.response.status_code == 404:
                    print("Erro: Arquivo não encontrado.")
                    break  # Não é necessário tentar novamente se o arquivo não existe
                else:
                    print(f"Erro ao baixar o arquivo ZIP '{file_name}': {e}")
                    time.sleep(5)  # Aguarde 5 segundos antes de tentar novamente
            else:
                print(f"Erro ao baixar o arquivo ZIP '{file_name}': {e}")
                break

url2 = 2557
while url2 <= 2742:
    zip_url = 'http://revistas.inpi.gov.br/txt/P' + str(url2) + '.zip'
    # Pasta onde você deseja salvar o arquivo ZIP
    output_folder = 'dados_zip'

    # Verifique se a pasta de saída existe e a crie se não existir
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    download_zip(zip_url, output_folder)
    url2 += 1
# Out:
# Arquivo ZIP 'P2557.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2558.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2559.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2560.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2561.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2562.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2563.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2564.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2565.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2566.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2567.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2568.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2569.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2570.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2571.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2572.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2573.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2574.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2575.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2576.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2577.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2578.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2579.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2580.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2581.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2582.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2583.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2584.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2585.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2586.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2587.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2588.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2589.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2590.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2591.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2592.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2593.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2594.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2595.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2596.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2597.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2598.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2599.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2600.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2601.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2602.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2603.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2604.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2605.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2606.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2607.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2608.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2609.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2610.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2611.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2612.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2613.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2614.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2615.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2616.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2617.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2618.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2619.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2620.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2621.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2622.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2623.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2624.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2625.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2626.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2627.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2628.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2629.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2630.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2631.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2632.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2633.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2634.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2635.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2636.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2637.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2638.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2639.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2640.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2641.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2642.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2643.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2644.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2645.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2646.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2647.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2648.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2649.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2650.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2651.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2652.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2653.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2654.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2655.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2656.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2657.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2658.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2659.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2660.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2661.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2662.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2663.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2664.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2665.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2666.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2667.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2668.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2669.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2670.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2671.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2672.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2673.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2674.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2675.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2676.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2677.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2678.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2679.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2680.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2681.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2682.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2683.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2684.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2685.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2686.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2687.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2688.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2689.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2690.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2691.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2692.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2693.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2694.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2695.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2696.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2697.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2698.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2699.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2700.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2701.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2702.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2703.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2704.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2705.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2706.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2707.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2708.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2709.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2710.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2711.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2712.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2713.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2714.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2715.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2716.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2717.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2718.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2719.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2720.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2721.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2722.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2723.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2724.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2725.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2726.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2727.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2728.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2729.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2730.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2731.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2732.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2733.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2734.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2735.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2736.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2737.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2738.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2739.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2740.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2741.zip' já existe na pasta, pulando o download.
# Arquivo ZIP 'P2742.zip' já existe na pasta, pulando o download.

# %% [markdown]
# ## Descompactar e organizar os arquivos

# %%
def extract_zip_files(output_folder):
    # Certifique-se de que a pasta de saída existe
    if not os.path.exists(output_folder):
        print(f"A pasta de saída '{output_folder}' não existe.")
        return

    # Pasta onde você deseja salvar os arquivos XML extraídos
    xml_folder = 'dados_xml'

    # Verifique se a pasta de saída para os XML existe e a crie se não existir
    if not os.path.exists(xml_folder):
        os.makedirs(xml_folder)

    # Percorre todos os arquivos na pasta de saída
    for root, dirs, files in os.walk(output_folder):
        for file in files:
            if file.lower().endswith(".zip"):
                zip_path = os.path.join(root, file)

                try:
                    # Abra o arquivo ZIP
                    with zipfile.ZipFile(zip_path, "r") as zipf:
                        for filename in zipf.namelist():
                            if filename.startswith("Patente_"):
                                # Extraia o arquivo XML correspondente
                                with zipf.open(filename) as xml_file:
                                    xml_content = xml_file.read()
                                    xml_filename = os.path.join(xml_folder, filename)
                                    with open(xml_filename, "wb") as output_file:
                                        output_file.write(xml_content)

                                # Move o arquivo XML extraído com sucesso para a pasta 'dados_xml'
                                os.rename(xml_filename, os.path.join(xml_folder, filename))
                                print(f"Arquivo XML {filename} extraído com sucesso em '{xml_filename}' e movido para '{xml_folder}'")
                except zipfile.BadZipFile:
                    print(f"Erro ao extrair o arquivo ZIP '{file}': Arquivo ZIP inválido.")
                except Exception as e:
                    print(f"Erro ao processar o arquivo ZIP '{file}': {e}")

# Exemplo de uso
extract_zip_files('dados_zip')
# Out:
# Arquivo XML Patente_2557_07012020.xml extraído com sucesso em 'dados_xml\Patente_2557_07012020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2558_14012020.xml extraído com sucesso em 'dados_xml\Patente_2558_14012020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2559_21012020.xml extraído com sucesso em 'dados_xml\Patente_2559_21012020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2560_28012020.xml extraído com sucesso em 'dados_xml\Patente_2560_28012020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2561_04022020.xml extraído com sucesso em 'dados_xml\Patente_2561_04022020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2562_11022020.xml extraído com sucesso em 'dados_xml\Patente_2562_11022020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2563_18022020.xml extraído com sucesso em 'dados_xml\Patente_2563_18022020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2564_27022020.xml extraído com sucesso em 'dados_xml\Patente_2564_27022020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2565_03032020.xml extraído com sucesso em 'dados_xml\Patente_2565_03032020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2566_10032020.xml extraído com sucesso em 'dados_xml\Patente_2566_10032020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2567_17032020.xml extraído com sucesso em 'dados_xml\Patente_2567_17032020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2568_24032020.xml extraído com sucesso em 'dados_xml\Patente_2568_24032020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2569_31032020.xml extraído com sucesso em 'dados_xml\Patente_2569_31032020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2570_07042020.xml extraído com sucesso em 'dados_xml\Patente_2570_07042020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2571_14042020.xml extraído com sucesso em 'dados_xml\Patente_2571_14042020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2572_22042020.xml extraído com sucesso em 'dados_xml\Patente_2572_22042020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2573_28042020.xml extraído com sucesso em 'dados_xml\Patente_2573_28042020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2574_05052020.xml extraído com sucesso em 'dados_xml\Patente_2574_05052020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2575_12052020.xml extraído com sucesso em 'dados_xml\Patente_2575_12052020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2576_19052020.xml extraído com sucesso em 'dados_xml\Patente_2576_19052020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2577_26052020.xml extraído com sucesso em 'dados_xml\Patente_2577_26052020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2578_02062020.xml extraído com sucesso em 'dados_xml\Patente_2578_02062020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2579_09062020.xml extraído com sucesso em 'dados_xml\Patente_2579_09062020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2580_16062020.xml extraído com sucesso em 'dados_xml\Patente_2580_16062020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2581_23062020.xml extraído com sucesso em 'dados_xml\Patente_2581_23062020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2582_30062020.xml extraído com sucesso em 'dados_xml\Patente_2582_30062020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2583_07072020.xml extraído com sucesso em 'dados_xml\Patente_2583_07072020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2584_14072020.xml extraído com sucesso em 'dados_xml\Patente_2584_14072020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2585_21072020.xml extraído com sucesso em 'dados_xml\Patente_2585_21072020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2586_28072020.xml extraído com sucesso em 'dados_xml\Patente_2586_28072020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2587_04082020.xml extraído com sucesso em 'dados_xml\Patente_2587_04082020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2588_11082020.xml extraído com sucesso em 'dados_xml\Patente_2588_11082020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2589_18082020.xml extraído com sucesso em 'dados_xml\Patente_2589_18082020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2590_25082020.xml extraído com sucesso em 'dados_xml\Patente_2590_25082020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2591_01092020.xml extraído com sucesso em 'dados_xml\Patente_2591_01092020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2592_08092020.xml extraído com sucesso em 'dados_xml\Patente_2592_08092020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2593_15092020.xml extraído com sucesso em 'dados_xml\Patente_2593_15092020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2594_24092020.xml extraído com sucesso em 'dados_xml\Patente_2594_24092020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2595_29092020.xml extraído com sucesso em 'dados_xml\Patente_2595_29092020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2596_06102020.xml extraído com sucesso em 'dados_xml\Patente_2596_06102020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2597_13102020.xml extraído com sucesso em 'dados_xml\Patente_2597_13102020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2598_20102020.xml extraído com sucesso em 'dados_xml\Patente_2598_20102020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2599_27102020.xml extraído com sucesso em 'dados_xml\Patente_2599_27102020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2600_03112020.xml extraído com sucesso em 'dados_xml\Patente_2600_03112020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2601_10112020.xml extraído com sucesso em 'dados_xml\Patente_2601_10112020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2602_17112020.xml extraído com sucesso em 'dados_xml\Patente_2602_17112020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2603_24112020.xml extraído com sucesso em 'dados_xml\Patente_2603_24112020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2604_01122020.xml extraído com sucesso em 'dados_xml\Patente_2604_01122020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2605_08122020.xml extraído com sucesso em 'dados_xml\Patente_2605_08122020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2606_15122020.xml extraído com sucesso em 'dados_xml\Patente_2606_15122020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2607_22122020.xml extraído com sucesso em 'dados_xml\Patente_2607_22122020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2608_29122020.xml extraído com sucesso em 'dados_xml\Patente_2608_29122020.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2609_05012021.xml extraído com sucesso em 'dados_xml\Patente_2609_05012021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2610_12012021.xml extraído com sucesso em 'dados_xml\Patente_2610_12012021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2611_19012021.xml extraído com sucesso em 'dados_xml\Patente_2611_19012021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2612_26012021.xml extraído com sucesso em 'dados_xml\Patente_2612_26012021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2613_02022021.xml extraído com sucesso em 'dados_xml\Patente_2613_02022021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2614_09022021.xml extraído com sucesso em 'dados_xml\Patente_2614_09022021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2615_17022021.xml extraído com sucesso em 'dados_xml\Patente_2615_17022021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2616_23022021.xml extraído com sucesso em 'dados_xml\Patente_2616_23022021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2617_02032021.xml extraído com sucesso em 'dados_xml\Patente_2617_02032021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2618_09032021.xml extraído com sucesso em 'dados_xml\Patente_2618_09032021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2619_16032021.xml extraído com sucesso em 'dados_xml\Patente_2619_16032021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2620_23032021.xml extraído com sucesso em 'dados_xml\Patente_2620_23032021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2621_30032021.xml extraído com sucesso em 'dados_xml\Patente_2621_30032021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2622_06042021.xml extraído com sucesso em 'dados_xml\Patente_2622_06042021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2623_13042021.xml extraído com sucesso em 'dados_xml\Patente_2623_13042021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2624_20042021.xml extraído com sucesso em 'dados_xml\Patente_2624_20042021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2625_27042021.xml extraído com sucesso em 'dados_xml\Patente_2625_27042021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2626_04052021.xml extraído com sucesso em 'dados_xml\Patente_2626_04052021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2627_11052021.xml extraído com sucesso em 'dados_xml\Patente_2627_11052021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2628_18052021.xml extraído com sucesso em 'dados_xml\Patente_2628_18052021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2629_25052021.xml extraído com sucesso em 'dados_xml\Patente_2629_25052021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2630_01062021.xml extraído com sucesso em 'dados_xml\Patente_2630_01062021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2631_08062021.xml extraído com sucesso em 'dados_xml\Patente_2631_08062021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2632_15062021.xml extraído com sucesso em 'dados_xml\Patente_2632_15062021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2633_22062021.xml extraído com sucesso em 'dados_xml\Patente_2633_22062021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2634_29062021.xml extraído com sucesso em 'dados_xml\Patente_2634_29062021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2635_06072021.xml extraído com sucesso em 'dados_xml\Patente_2635_06072021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2636_13072021.xml extraído com sucesso em 'dados_xml\Patente_2636_13072021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2637_20072021.xml extraído com sucesso em 'dados_xml\Patente_2637_20072021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2638_27072021.xml extraído com sucesso em 'dados_xml\Patente_2638_27072021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2639_03082021.xml extraído com sucesso em 'dados_xml\Patente_2639_03082021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2640_10082021.xml extraído com sucesso em 'dados_xml\Patente_2640_10082021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2641_17082021.xml extraído com sucesso em 'dados_xml\Patente_2641_17082021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2642_24082021.xml extraído com sucesso em 'dados_xml\Patente_2642_24082021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2643_31082021.xml extraído com sucesso em 'dados_xml\Patente_2643_31082021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2644_08092021.xml extraído com sucesso em 'dados_xml\Patente_2644_08092021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2645_14092021.xml extraído com sucesso em 'dados_xml\Patente_2645_14092021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2646_21092021.xml extraído com sucesso em 'dados_xml\Patente_2646_21092021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2647_28092021.xml extraído com sucesso em 'dados_xml\Patente_2647_28092021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2648_05102021.xml extraído com sucesso em 'dados_xml\Patente_2648_05102021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2649_13102021.xml extraído com sucesso em 'dados_xml\Patente_2649_13102021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2650_19102021.xml extraído com sucesso em 'dados_xml\Patente_2650_19102021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2651_26102021.xml extraído com sucesso em 'dados_xml\Patente_2651_26102021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2652_03112021.xml extraído com sucesso em 'dados_xml\Patente_2652_03112021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2653_09112021.xml extraído com sucesso em 'dados_xml\Patente_2653_09112021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2654_16112021.xml extraído com sucesso em 'dados_xml\Patente_2654_16112021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2655_23112021.xml extraído com sucesso em 'dados_xml\Patente_2655_23112021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2656_30112021.xml extraído com sucesso em 'dados_xml\Patente_2656_30112021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2657_07122021.xml extraído com sucesso em 'dados_xml\Patente_2657_07122021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2658_14122021.xml extraído com sucesso em 'dados_xml\Patente_2658_14122021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2659_21122021.xml extraído com sucesso em 'dados_xml\Patente_2659_21122021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2660_28122021.xml extraído com sucesso em 'dados_xml\Patente_2660_28122021.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2661_04012022.xml extraído com sucesso em 'dados_xml\Patente_2661_04012022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2662_11012022.xml extraído com sucesso em 'dados_xml\Patente_2662_11012022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2663_18012022.xml extraído com sucesso em 'dados_xml\Patente_2663_18012022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2664_25012022.xml extraído com sucesso em 'dados_xml\Patente_2664_25012022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2665_01022022.xml extraído com sucesso em 'dados_xml\Patente_2665_01022022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2666_08022022.xml extraído com sucesso em 'dados_xml\Patente_2666_08022022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2667_15022022.xml extraído com sucesso em 'dados_xml\Patente_2667_15022022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2668_22022022.xml extraído com sucesso em 'dados_xml\Patente_2668_22022022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2669_03032022.xml extraído com sucesso em 'dados_xml\Patente_2669_03032022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2670_08032022.xml extraído com sucesso em 'dados_xml\Patente_2670_08032022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2671_15032022.xml extraído com sucesso em 'dados_xml\Patente_2671_15032022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2672_22032022.xml extraído com sucesso em 'dados_xml\Patente_2672_22032022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2673_29032022.xml extraído com sucesso em 'dados_xml\Patente_2673_29032022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2674_05042022.xml extraído com sucesso em 'dados_xml\Patente_2674_05042022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2675_12042022.xml extraído com sucesso em 'dados_xml\Patente_2675_12042022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2676_19042022.xml extraído com sucesso em 'dados_xml\Patente_2676_19042022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2677_26042022.xml extraído com sucesso em 'dados_xml\Patente_2677_26042022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2678_03052022.xml extraído com sucesso em 'dados_xml\Patente_2678_03052022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2679_10052022.xml extraído com sucesso em 'dados_xml\Patente_2679_10052022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2680_17052022.xml extraído com sucesso em 'dados_xml\Patente_2680_17052022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2681_24052022.xml extraído com sucesso em 'dados_xml\Patente_2681_24052022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2682_31052022.xml extraído com sucesso em 'dados_xml\Patente_2682_31052022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2683_07062022.xml extraído com sucesso em 'dados_xml\Patente_2683_07062022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2684_14062022.xml extraído com sucesso em 'dados_xml\Patente_2684_14062022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2685_21062022.xml extraído com sucesso em 'dados_xml\Patente_2685_21062022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2686_28062022.xml extraído com sucesso em 'dados_xml\Patente_2686_28062022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2687_05072022.xml extraído com sucesso em 'dados_xml\Patente_2687_05072022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2688_12072022.xml extraído com sucesso em 'dados_xml\Patente_2688_12072022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2689_19072022.xml extraído com sucesso em 'dados_xml\Patente_2689_19072022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2690_26072022.xml extraído com sucesso em 'dados_xml\Patente_2690_26072022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2691_02082022.xml extraído com sucesso em 'dados_xml\Patente_2691_02082022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2692_09082022.xml extraído com sucesso em 'dados_xml\Patente_2692_09082022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2693_16082022.xml extraído com sucesso em 'dados_xml\Patente_2693_16082022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2694_23082022.xml extraído com sucesso em 'dados_xml\Patente_2694_23082022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2695_30082022.xml extraído com sucesso em 'dados_xml\Patente_2695_30082022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2696_06092022.xml extraído com sucesso em 'dados_xml\Patente_2696_06092022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2697_13092022.xml extraído com sucesso em 'dados_xml\Patente_2697_13092022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2698_20092022.xml extraído com sucesso em 'dados_xml\Patente_2698_20092022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2699_27092022.xml extraído com sucesso em 'dados_xml\Patente_2699_27092022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2700_04102022.xml extraído com sucesso em 'dados_xml\Patente_2700_04102022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2701_11102022.xml extraído com sucesso em 'dados_xml\Patente_2701_11102022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2702_18102022.xml extraído com sucesso em 'dados_xml\Patente_2702_18102022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2703_25102022.xml extraído com sucesso em 'dados_xml\Patente_2703_25102022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2704_01112022.xml extraído com sucesso em 'dados_xml\Patente_2704_01112022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2705_08112022.xml extraído com sucesso em 'dados_xml\Patente_2705_08112022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2706_16112022.xml extraído com sucesso em 'dados_xml\Patente_2706_16112022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2707_22112022.xml extraído com sucesso em 'dados_xml\Patente_2707_22112022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2708_29112022.xml extraído com sucesso em 'dados_xml\Patente_2708_29112022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2709_06122022.xml extraído com sucesso em 'dados_xml\Patente_2709_06122022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2710_13122022.xml extraído com sucesso em 'dados_xml\Patente_2710_13122022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2711_20122022.xml extraído com sucesso em 'dados_xml\Patente_2711_20122022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2712_27122022.xml extraído com sucesso em 'dados_xml\Patente_2712_27122022.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2713_03012023.xml extraído com sucesso em 'dados_xml\Patente_2713_03012023.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2714_10012023.xml extraído com sucesso em 'dados_xml\Patente_2714_10012023.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2715_17012023.xml extraído com sucesso em 'dados_xml\Patente_2715_17012023.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2716_24012023.xml extraído com sucesso em 'dados_xml\Patente_2716_24012023.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2717_31012023.xml extraído com sucesso em 'dados_xml\Patente_2717_31012023.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2718_07022023.xml extraído com sucesso em 'dados_xml\Patente_2718_07022023.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2719_14022023.xml extraído com sucesso em 'dados_xml\Patente_2719_14022023.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2720_23022023.xml extraído com sucesso em 'dados_xml\Patente_2720_23022023.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2721_28022023.xml extraído com sucesso em 'dados_xml\Patente_2721_28022023.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2722_07032023.xml extraído com sucesso em 'dados_xml\Patente_2722_07032023.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2723_14032023.xml extraído com sucesso em 'dados_xml\Patente_2723_14032023.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2724_21032023.xml extraído com sucesso em 'dados_xml\Patente_2724_21032023.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2725_28032023.xml extraído com sucesso em 'dados_xml\Patente_2725_28032023.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2726_04042023.xml extraído com sucesso em 'dados_xml\Patente_2726_04042023.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2727_11042023.xml extraído com sucesso em 'dados_xml\Patente_2727_11042023.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2728_18042023.xml extraído com sucesso em 'dados_xml\Patente_2728_18042023.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2729_25042023.xml extraído com sucesso em 'dados_xml\Patente_2729_25042023.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2730_02052023.xml extraído com sucesso em 'dados_xml\Patente_2730_02052023.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2731_09052023.xml extraído com sucesso em 'dados_xml\Patente_2731_09052023.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2732_16052023.xml extraído com sucesso em 'dados_xml\Patente_2732_16052023.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2733_23052023.xml extraído com sucesso em 'dados_xml\Patente_2733_23052023.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2734_30052023.xml extraído com sucesso em 'dados_xml\Patente_2734_30052023.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2735_06062023.xml extraído com sucesso em 'dados_xml\Patente_2735_06062023.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2736_13062023.xml extraído com sucesso em 'dados_xml\Patente_2736_13062023.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2737_20062023.xml extraído com sucesso em 'dados_xml\Patente_2737_20062023.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2738_27062023.xml extraído com sucesso em 'dados_xml\Patente_2738_27062023.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2739_04072023.xml extraído com sucesso em 'dados_xml\Patente_2739_04072023.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2740_11072023.xml extraído com sucesso em 'dados_xml\Patente_2740_11072023.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2741_18072023.xml extraído com sucesso em 'dados_xml\Patente_2741_18072023.xml' e movido para 'dados_xml'
# Arquivo XML Patente_2742_25072023.xml extraído com sucesso em 'dados_xml\Patente_2742_25072023.xml' e movido para 'dados_xml'

# %% [markdown]
# ## Raspagem dos dados

# %%
# Definir função para raspagem de um arquivo xml
def raspagem(root):
    # Inicializar listas para armazenar os dados
    data_publicacao = []
    diretoria = []
    numero_revista = []
    codigo = []
    titulo = []
    numero = []
    data_deposito = []
    data_prioridade = []
    cod_prioridade = []
    classificacoes_internacionais = []
    classificacoes_nacionais = []
    titulo_inid = []
    titular_nome = []
    titular_uf = []
    titular_pais = []
    inventor_nome = []

    # Extrair os dados do XML
    for despacho in root.findall(".//despacho[codigo='3.1']"):
        data_publ = root.get('dataPublicacao')
        diret = root.get('diretoria')
        num_rev = root.get('numero')
        cod = despacho.find('codigo').text if despacho.find('codigo') is not None else None
        if cod != None:
            tit = despacho.find('titulo').text if despacho.find('titulo') is not None else None
            processo_patente = despacho.find('processo-patente')
            num = processo_patente.find('.//numero[@inid="21"]').text if processo_patente.find('.//numero[@inid="21"]') is not None else None
            data = processo_patente.find('.//data-deposito[@inid="22"]').text if processo_patente.find('.//data-deposito[@inid="22"]') is not None else None
            data_prio = despacho.find(".//data-prioridade[@inid='31']").text if despacho.find(".//data-prioridade[@inid='31']") is not None else None
            cod_prio1 = despacho.find(".//sigla-pais[@inid='33']").text if despacho.find(".//sigla-pais[@inid='33']") is not None else None
            cod_prio2 = despacho.find(".//numero-prioridade[@inid='32']").text if despacho.find(".//numero-prioridade[@inid='32']") is not None else None
            cod_prio = cod_prio1 + cod_prio2 if (cod_prio1 is not None and cod_prio2 is not None) else None
            internacionais1 = despacho.findall(".//classificacao-internacional[@inid='51']")
            internacionais = '; '.join(ci.text for ci in internacionais1) if internacionais1 else None
            nacionais1 = despacho.findall(".//classificacao-nacional[@inid='52']")
            nacionais = '; '.join(cn.text for cn in nacionais1) if nacionais1 else None
            tit_inid = despacho.find(".//titulo[@inid='54']").text if despacho.find(".//titulo[@inid='54']") is not None else None
            titulares1 = despacho.findall(".//titular[@inid='71']")
            titu_nome = '; '.join(t.find(".//nome-completo").text for t in titulares1) if titulares1 else None
            titu_uf = '; '.join(t.text for t in despacho.findall(".//uf")) if titulares1 else None
            titu_pais = '; '.join(t.text for t in despacho.findall(".//sigla")) if titulares1 else None
            inventores1 = despacho.findall(".//inventor[@inid='72']")
            invent_nome = '; '.join(t.find(".//nome-completo").text for t in inventores1) if inventores1 else None
            # Incluir os dados nas listas
            data_publicacao.append(data_publ)
            diretoria.append(diret)
            numero_revista.append(num_rev)
            codigo.append(cod)
            titulo.append(tit)
            numero.append(num)
            data_deposito.append(data)
            data_prioridade.append(data_prio)
            cod_prioridade.append(cod_prio)
            classificacoes_internacionais.append(internacionais)
            classificacoes_nacionais.append(nacionais)
            titulo_inid.append(tit_inid)
            titular_nome.append(titu_nome)
            titular_uf.append(titu_uf)
            titular_pais.append(titu_pais)
            inventor_nome.append(invent_nome)
        else:
            data_publ = root.get('dataPublicacao')
            diret = root.get('diretoria')
            num_rev = root.get('numero')
            # Incluir os dados na lista
            data_publicacao.append(data_publ)
            diretoria.append(diret)
            numero_revista.append(num_rev)
            codigo.append(None)
            titulo.append(None)
            numero.append(None)
            data_deposito.append(None)
            data_prioridade.append(None)
            cod_prioridade.append(None)
            classificacoes_internacionais.append(None)
            classificacoes_nacionais.append(None)
            titulo_inid.append(None)
            titular_nome.append(None)
            titular_uf.append(None)
            titular_pais.append(None)
            inventor_nome.append(None)

    # Transformar listas em um DataFrame
    df = pd.DataFrame({
        'data_publicacao': data_publicacao,
        'diretoria': diretoria,
        'numero_revista': numero_revista,
        'codigo': codigo,
        'titulo': titulo,
        'numero': numero,
        'data_deposito': data_deposito,
        'data_prioridade': data_prioridade,
        'cod_prioridade': cod_prioridade,
        'classif_internacion': classificacoes_internacionais,
        'classif_nacion': classificacoes_nacionais,
        'titulo_inid': titulo_inid,
        'titular_nome': titular_nome,
        'titular_uf': titular_uf,
        'titular_pais': titular_pais,
        'inventor_nome': inventor_nome
    })

    return df

# %% [markdown]
# ## Salvar dataframe completo

# %%
# Inicializar o dataframe
data = pd.DataFrame()

# Inicializar o timer
start_time = time.time()

# Lista de arquivos
arquivos = os.listdir('dados_xml')

# Inicializar a barra de progresso
with tqdm(total=len(arquivos), desc="Processando arquivos") as pbar:
    for file in arquivos:
        filepath = os.path.join('dados_xml', file)
        tree = ET.parse(filepath)
        root = tree.getroot()
        df = raspagem(root)
        data = pd.concat([data, df], axis=0)
        pbar.update(1)

# Finalizar o timer
end_time = time.time()

# Calcular o tempo decorrido
tempo_decorrido = end_time - start_time

print(f"Tempo decorrido: {tempo_decorrido:.2f} segundos")
# Out:
# Processando arquivos: 100%|██████████| 186/186 [01:21<00:00,  2.28it/s]
# Tempo decorrido: 81.78 segundos

# %%
data.head(5)
# Out:
#   data_publicacao diretoria numero_revista codigo  \
# 0      07/01/2020   Patente           2557    3.1
# 1      07/01/2020   Patente           2557    3.1
# 2      07/01/2020   Patente           2557    3.1
# 3      07/01/2020   Patente           2557    3.1
# 4      07/01/2020   Patente           2557    3.1
#
#                                               titulo               numero  \
# 0  Publicação do Pedido de Patente ou de Certific...  BR 10 2013 016644-8
# 1  Publicação do Pedido de Patente ou de Certific...  BR 10 2014 001105-6
# 2  Publicação do Pedido de Patente ou de Certific...  BR 10 2017 004929-9
# 3  Publicação do Pedido de Patente ou de Certific...  BR 10 2017 024659-0
# 4  Publicação do Pedido de Patente ou de Certific...  BR 10 2017 026178-6
#
#   data_deposito data_prioridade cod_prioridade  \
# 0    27/06/2013            None           None
# 1    16/01/2014      18/01/2013    TW102201214
# 2    13/03/2017            None           None
# 3    17/11/2017            None           None
# 4    05/12/2017            None           None
#
#                   classif_internacion  \
# 0  B29B 17/00; B29C 43/00; B29K 31/00
# 1               F16C 11/04; E05F 1/12
# 2               H01Q 13/10; H01Q 1/24
# 3                G01F 1/58; H04W 4/12
# 4              H04L 29/06; H04L 29/12
#
#                             classif_nacion  \
# 0                   B29B 17/00; B29C 43/00
# 1                  F16C 11/04; E05F 1/1215
# 2                  H01Q 13/106; H01Q 1/241
# 3                     G01F 1/58; H04W 4/12
# 4  H04L 67/42; H04L 61/1558; H04L 29/12141
#
#                                          titulo_inid  \
# 0  APERFEIÇOAMENTO INTRODUZIDO EM PROCESSO DE REC...
# 1        DOBRADIÇA PARA CONJUNTO DE CAPAS PROTETORAS
# 2  UMA NOVA ANTENA DE MICROFITA TRI-BANDA, DE TAM...
# 3  DISPOSITIVO DE MÚLTIPLOS MÓDULOS COM OTIMIZAÇÃ...
# 4  BEHAVIOR DEFINITION MODEL FOR INTERNET OF THIN...
#
#                         titular_nome titular_uf titular_pais  \
# 0            ACM EL ORRA COLCHÕES ME         SP           BR
# 1        KEYARROW (TAIWAN) CO., LTD.                      TW
# 2      UNIVERSIDADE FEDERAL DO CEARÁ         CE           BR
# 3              CID GRANJA DOS SANTOS                      BR
# 4  FUNDAÇÃO UNIVERSIDADE DO AMAZONAS         AM           BR
#
#                                        inventor_nome
# 0                         ABDO CARIM MOUMTEZ EL ORRA
# 1                           FU-YI CHEN; CHI, LI-LING
# 2  ANTONIO SERGIO BEZERRA SOMBRA; RONALDO GLAUBER...
# 3                              CID GRANJA DOS SANTOS
# 4  EDUARDO JAMES PEREIRA SOUTO; NAMEDIN PEREIRA T...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24714 entries, 0 to 57
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   data_publicacao      24714 non-null  object
#  1   diretoria            24714 non-null  object
#  2   numero_revista       24714 non-null  object
#  3   codigo               24714 non-null  object
#  4   titulo               24714 non-null  object
#  5   numero               24714 non-null  object
#  6   data_deposito        24714 non-null  object
#  7   data_prioridade      5052 non-null   object
#  8   cod_prioridade       5052 non-null   object
#  9   classif_internacion  24223 non-null  object
#  10  classif_nacion       17269 non-null  object
#  11  titulo_inid          24714 non-null  object
#  12  titular_nome         24714 non-null  object
#  13  titular_uf           24714 non-null  object
#  14  titular_pais         24714 non-null  object
#  15  inventor_nome        24714 non-null  object
# dtypes: object(16)
# memory usage: 3.2+ MB

# %% [markdown]
# ## Tratamento dos dados

# %%
# Salvar o DataFrame em um arquivo CSV
data.to_csv('data_patentes.csv', index=False)

# %%
# Exporte o DataFrame para o arquivo Excel
data.to_excel('data_patentes_excel.xlsx', sheet_name='Planilha Patentes', index=False)
