# %% [markdown]
# # Mapeamento de patentes

# %% [markdown]
# ## Bibliotecas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Limpeza (semiautomatizada)

# %%
data = pd.read_excel('data_patentes_excel.xlsx')
data.insert(0, 'ID', ["ID{:05d}".format(i) for i in range(1, len(data) + 1)])

# %%
responsavel = ["Titular"] +["Parceiro{:02d}".format(i) for i in range(1, 35)]
data_largo = data.copy()
data_largo[responsavel] = data_largo['titular_nome'].str.split(';', expand=True)
data.head(5)
# Out:
#         ID data_publicacao diretoria  numero_revista  codigo  \
# 0  ID00001      07/01/2020   Patente            2557     3.1
# 1  ID00002      07/01/2020   Patente            2557     3.1
# 2  ID00003      07/01/2020   Patente            2557     3.1
# 3  ID00004      07/01/2020   Patente            2557     3.1
# 4  ID00005      07/01/2020   Patente            2557     3.1
#
#                                               titulo               numero  \
# 0  Publicação do Pedido de Patente ou de Certific...  BR 10 2013 016644-8
# 1  Publicação do Pedido de Patente ou de Certific...  BR 10 2014 001105-6
# 2  Publicação do Pedido de Patente ou de Certific...  BR 10 2017 004929-9
# 3  Publicação do Pedido de Patente ou de Certific...  BR 10 2017 024659-0
# 4  Publicação do Pedido de Patente ou de Certific...  BR 10 2017 026178-6
#
#   data_deposito data_prioridade cod_prioridade  \
# 0    27/06/2013             NaN            NaN
# 1    16/01/2014      18/01/2013    TW102201214
# 2    13/03/2017             NaN            NaN
# 3    17/11/2017             NaN            NaN
# 4    05/12/2017             NaN            NaN
#
#                   classif_internacion  \
# 0  B29B 17/00; B29C 43/00; B29K 31/00
# 1               F16C 11/04; E05F 1/12
# 2               H01Q 13/10; H01Q 1/24
# 3                G01F 1/58; H04W 4/12
# 4              H04L 29/06; H04L 29/12
#
#                             classif_nacion  \
# 0                   B29B 17/00; B29C 43/00
# 1                  F16C 11/04; E05F 1/1215
# 2                  H01Q 13/106; H01Q 1/241
# 3                     G01F 1/58; H04W 4/12
# 4  H04L 67/42; H04L 61/1558; H04L 29/12141
#
#                                          titulo_inid  \
# 0  APERFEIÇOAMENTO INTRODUZIDO EM PROCESSO DE REC...
# 1        DOBRADIÇA PARA CONJUNTO DE CAPAS PROTETORAS
# 2  UMA NOVA ANTENA DE MICROFITA TRI-BANDA, DE TAM...
# 3  DISPOSITIVO DE MÚLTIPLOS MÓDULOS COM OTIMIZAÇÃ...
# 4  BEHAVIOR DEFINITION MODEL FOR INTERNET OF THIN...
#
#                         titular_nome titular_uf titular_pais  \
# 0            ACM EL ORRA COLCHÕES ME         SP           BR
# 1        KEYARROW (TAIWAN) CO., LTD.        NaN           TW
# 2      UNIVERSIDADE FEDERAL DO CEARÁ         CE           BR
# 3              CID GRANJA DOS SANTOS        NaN           BR
# 4  FUNDAÇÃO UNIVERSIDADE DO AMAZONAS         AM           BR
#
#                                        inventor_nome
# 0                         ABDO CARIM MOUMTEZ EL ORRA
# 1                           FU-YI CHEN; CHI, LI-LING
# 2  ANTONIO SERGIO BEZERRA SOMBRA; RONALDO GLAUBER...
# 3                              CID GRANJA DOS SANTOS
# 4  EDUARDO JAMES PEREIRA SOUTO; NAMEDIN PEREIRA T...

# %%
data_largo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24714 entries, 0 to 24713
# Data columns (total 52 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   24714 non-null  object
#  1   data_publicacao      24714 non-null  object
#  2   diretoria            24714 non-null  object
#  3   numero_revista       24714 non-null  int64
#  4   codigo               24714 non-null  float64
#  5   titulo               24714 non-null  object
#  6   numero               24714 non-null  object
#  7   data_deposito        24714 non-null  object
#  8   data_prioridade      5052 non-null   object
#  9   cod_prioridade       5052 non-null   object
#  10  classif_internacion  24223 non-null  object
#  11  classif_nacion       17269 non-null  object
#  12  titulo_inid          24714 non-null  object
#  13  titular_nome         24714 non-null  object
#  14  titular_uf           19438 non-null  object
#  15  titular_pais         24714 non-null  object
#  16  inventor_nome        24714 non-null  object
#  17  Titular              24714 non-null  object
#  18  Parceiro01           3272 non-null   object
#  19  Parceiro02           757 non-null    object
#  20  Parceiro03           216 non-null    object
#  21  Parceiro04           106 non-null    object
#  22  Parceiro05           55 non-null     object
#  23  Parceiro06           33 non-null     object
#  24  Parceiro07           21 non-null     object
#  25  Parceiro08           18 non-null     object
#  26  Parceiro09           11 non-null     object
#  27  Parceiro10           4 non-null      object
#  28  Parceiro11           1 non-null      object
#  29  Parceiro12           1 non-null      object
#  30  Parceiro13           1 non-null      object
#  31  Parceiro14           1 non-null      object
#  32  Parceiro15           1 non-null      object
#  33  Parceiro16           1 non-null      object
#  34  Parceiro17           1 non-null      object
#  35  Parceiro18           1 non-null      object
#  36  Parceiro19           1 non-null      object
#  37  Parceiro20           1 non-null      object
#  38  Parceiro21           1 non-null      object
#  39  Parceiro22           1 non-null      object
#  40  Parceiro23           1 non-null      object
#  41  Parceiro24           1 non-null      object
#  42  Parceiro25           1 non-null      object
#  43  Parceiro26           1 non-null      object
#  44  Parceiro27           1 non-null      object
#  45  Parceiro28           1 non-null      object
#  46  Parceiro29           1 non-null      object
#  47  Parceiro30           1 non-null      object
#  48  Parceiro31           1 non-null      object
#  49  Parceiro32           1 non-null      object
#  50  Parceiro33           1 non-null      object
#  51  Parceiro34           1 non-null      object
# dtypes: float64(1), int64(1), object(50)
# memory usage: 9.8+ MB

# %%
data_melted = pd.melt(data_largo, 
                    id_vars=['ID'], 
                    value_vars=responsavel, 
                    var_name='parceria', 
                    value_name='responsavel').copy()

data_melted = data_melted.sort_values('ID')
data_melted = data_melted.dropna(subset = 'responsavel')
data_melted['responsavel'] = data_melted['responsavel'].str.strip()
data_melted['responsavel'] = data_melted['responsavel'].replace("  ", " ")
data_melted['responsavel'] = data_melted['responsavel'].replace("  ", " ")
data_melted.head(12)
# Out:
#             ID    parceria                                        responsavel
# 0      ID00001     Titular                            ACM EL ORRA COLCHÕES ME
# 1      ID00002     Titular                        KEYARROW (TAIWAN) CO., LTD.
# 2      ID00003     Titular                      UNIVERSIDADE FEDERAL DO CEARÁ
# 3      ID00004     Titular                              CID GRANJA DOS SANTOS
# 4      ID00005     Titular                  FUNDAÇÃO UNIVERSIDADE DO AMAZONAS
# 5      ID00006     Titular  MISSÃO SALESIANA DE MATO GROSSO UNIVERSIDADE C...
# 6      ID00007     Titular                                      GRENDENE S.A.
# 7      ID00008     Titular                                    RENTBRELLA S.A.
# 8      ID00009     Titular   FUNDAÇÃO UNIVERSIDADE ESTADUAL DO CEARÁ - FUNECE
# 9      ID00010     Titular                         MARCUS CEZAR KLAUTAU BONNA
# 24724  ID00011  Parceiro01                 UNIVERSIDADE FEDERAL DE PERNAMBUCO
# 10     ID00011     Titular  INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNO...

# %%
aux1 = data_melted.pivot(index='ID', columns='parceria', values='responsavel').reset_index()
aux2 = data_largo.iloc[:, 0:17]
data_largo = aux2.merge(aux1, on=['ID'], how='left')
data_largo.head(12)
# Out:
#          ID data_publicacao diretoria  numero_revista  codigo  \
# 0   ID00001      07/01/2020   Patente            2557     3.1
# 1   ID00002      07/01/2020   Patente            2557     3.1
# 2   ID00003      07/01/2020   Patente            2557     3.1
# 3   ID00004      07/01/2020   Patente            2557     3.1
# 4   ID00005      07/01/2020   Patente            2557     3.1
# 5   ID00006      07/01/2020   Patente            2557     3.1
# 6   ID00007      07/01/2020   Patente            2557     3.1
# 7   ID00008      07/01/2020   Patente            2557     3.1
# 8   ID00009      07/01/2020   Patente            2557     3.1
# 9   ID00010      07/01/2020   Patente            2557     3.1
# 10  ID00011      07/01/2020   Patente            2557     3.1
# 11  ID00012      07/01/2020   Patente            2557     3.1
#
#                                                titulo               numero  \
# 0   Publicação do Pedido de Patente ou de Certific...  BR 10 2013 016644-8
# 1   Publicação do Pedido de Patente ou de Certific...  BR 10 2014 001105-6
# 2   Publicação do Pedido de Patente ou de Certific...  BR 10 2017 004929-9
# 3   Publicação do Pedido de Patente ou de Certific...  BR 10 2017 024659-0
# 4   Publicação do Pedido de Patente ou de Certific...  BR 10 2017 026178-6
# 5   Publicação do Pedido de Patente ou de Certific...  BR 10 2017 027316-4
# 6   Publicação do Pedido de Patente ou de Certific...  BR 10 2018 001913-9
# 7   Publicação do Pedido de Patente ou de Certific...  BR 10 2018 009789-0
# 8   Publicação do Pedido de Patente ou de Certific...  BR 10 2018 009796-2
# 9   Publicação do Pedido de Patente ou de Certific...  BR 10 2018 011938-9
# 10  Publicação do Pedido de Patente ou de Certific...  BR 10 2018 012005-0
# 11  Publicação do Pedido de Patente ou de Certific...  BR 10 2018 012013-1
#
#    data_deposito data_prioridade cod_prioridade  ... Parceiro26 Parceiro27  \
# 0     27/06/2013             NaN            NaN  ...        NaN        NaN
# 1     16/01/2014      18/01/2013    TW102201214  ...        NaN        NaN
# 2     13/03/2017             NaN            NaN  ...        NaN        NaN
# 3     17/11/2017             NaN            NaN  ...        NaN        NaN
# 4     05/12/2017             NaN            NaN  ...        NaN        NaN
# 5     06/12/2017             NaN            NaN  ...        NaN        NaN
# 6     29/01/2018             NaN            NaN  ...        NaN        NaN
# 7     15/05/2018             NaN            NaN  ...        NaN        NaN
# 8     15/05/2018             NaN            NaN  ...        NaN        NaN
# 9     13/06/2018             NaN            NaN  ...        NaN        NaN
# 10    13/06/2018             NaN            NaN  ...        NaN        NaN
# 11    13/06/2018             NaN            NaN  ...        NaN        NaN
#
#    Parceiro28 Parceiro29 Parceiro30 Parceiro31 Parceiro32 Parceiro33  \
# 0         NaN        NaN        NaN        NaN        NaN        NaN
# 1         NaN        NaN        NaN        NaN        NaN        NaN
# 2         NaN        NaN        NaN        NaN        NaN        NaN
# 3         NaN        NaN        NaN        NaN        NaN        NaN
# 4         NaN        NaN        NaN        NaN        NaN        NaN
# 5         NaN        NaN        NaN        NaN        NaN        NaN
# 6         NaN        NaN        NaN        NaN        NaN        NaN
# 7         NaN        NaN        NaN        NaN        NaN        NaN
# 8         NaN        NaN        NaN        NaN        NaN        NaN
# 9         NaN        NaN        NaN        NaN        NaN        NaN
# 10        NaN        NaN        NaN        NaN        NaN        NaN
# 11        NaN        NaN        NaN        NaN        NaN        NaN
#
#    Parceiro34                                            Titular
# 0         NaN                            ACM EL ORRA COLCHÕES ME
# 1         NaN                        KEYARROW (TAIWAN) CO., LTD.
# 2         NaN                      UNIVERSIDADE FEDERAL DO CEARÁ
# 3         NaN                              CID GRANJA DOS SANTOS
# 4         NaN                  FUNDAÇÃO UNIVERSIDADE DO AMAZONAS
# 5         NaN  MISSÃO SALESIANA DE MATO GROSSO UNIVERSIDADE C...
# 6         NaN                                      GRENDENE S.A.
# 7         NaN                                    RENTBRELLA S.A.
# 8         NaN   FUNDAÇÃO UNIVERSIDADE ESTADUAL DO CEARÁ - FUNECE
# 9         NaN                         MARCUS CEZAR KLAUTAU BONNA
# 10        NaN  INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNO...
# 11        NaN                      JOSEFA TOMAZ PEREIRA DE SOUZA
#
# [12 rows x 52 columns]

# %% [markdown]
# ## Filtro das IFES

# %%
chave = r'FEDERAL|FEDEERAL|UNIFEI|UNIVERSIDADE DE BRASILIA|UNIVERSIDADE DE BRASÍLIA|UNIVERSIDADE DA INTEGRAÇÃO INTERNACIONAL|UNIVERSIDADE DA INTEGRACAO INTERNACIONAL'
filtro = data_melted['responsavel'].str.contains(chave, case=False, regex=True) & ~data_melted['responsavel'].str.contains('FEDERAL CRED', case=False, regex=True)
federais_melted = data_melted[filtro].copy()
federais_melted['ifes'] = 'Sim'
print(federais_melted.head())
print(federais_melted.info())
# Out:
#             ID    parceria                                        responsavel  \
# 2      ID00003     Titular                      UNIVERSIDADE FEDERAL DO CEARÁ
# 24724  ID00011  Parceiro01                 UNIVERSIDADE FEDERAL DE PERNAMBUCO
# 10     ID00011     Titular  INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNO...
# 14     ID00015     Titular  INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNO...
# 23     ID00024     Titular                 UNIVERSIDADE FEDERAL DE UBERLÂNDIA
#
#       ifes
# 2      Sim
# 24724  Sim
# 10     Sim
# 14     Sim
# 23     Sim
# <class 'pandas.core.frame.DataFrame'>
# Index: 4296 entries, 2 to 24658
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           4296 non-null   object
#  1   parceria     4296 non-null   object
#  2   responsavel  4296 non-null   object
#  3   ifes         4296 non-null   object
# dtypes: object(4)
# memory usage: 167.8+ KB
# None

# %%
tab = federais_melted.groupby('responsavel').agg(n=('responsavel', 'size')).reset_index()
tab = tab.sort_values(by='n', ascending=False)
print(tab["responsavel"])
# Out:
# 174                 UNIVERSIDADE FEDERAL DE MINAS GERAIS
# 156          UNIVERSIDADE FEDERAL DE CAMPINA GRANDE - PB
# 141                      UNIVERSIDADE FEDERAL DA PARAIBA
# 183                   UNIVERSIDADE FEDERAL DE PERNAMBUCO
# 205                   UNIVERSIDADE FEDERAL DE UBERLÂNDIA
#                              ...
# 125           UNIVERSIDADE  FEDERAL DE OURO PRETO - UFOP
# 126    UNIVERSIDADE DA INTEGRAÇÃO INTERNACIONAL DA LU...
# 128                       UNIVERSIDADE DE BRASILIA - UNB
# 130          UNIVERSIDADE FEDEERAL DE SANTA MARIA - UFSM
# 288                        Universidade Federal do Piauí
# Name: responsavel, Length: 289, dtype: object

# %%
#tab["responsavel"].to_excel('filtro.xlsx', sheet_name='Federais', index=False)

# %%
#Verificar dados
non_ifes_melted = data_melted[~filtro]
non_ifes_melted.head(15)
# Out:
#             ID    parceria                                        responsavel
# 0      ID00001     Titular                            ACM EL ORRA COLCHÕES ME
# 1      ID00002     Titular                        KEYARROW (TAIWAN) CO., LTD.
# 3      ID00004     Titular                              CID GRANJA DOS SANTOS
# 4      ID00005     Titular                  FUNDAÇÃO UNIVERSIDADE DO AMAZONAS
# 5      ID00006     Titular  MISSÃO SALESIANA DE MATO GROSSO UNIVERSIDADE C...
# 6      ID00007     Titular                                      GRENDENE S.A.
# 7      ID00008     Titular                                    RENTBRELLA S.A.
# 8      ID00009     Titular   FUNDAÇÃO UNIVERSIDADE ESTADUAL DO CEARÁ - FUNECE
# 9      ID00010     Titular                         MARCUS CEZAR KLAUTAU BONNA
# 49438  ID00011  Parceiro02  ASSOCIAÇÃO INSTITUTO DE TECNOLOGIA DE PERNAMBU...
# 11     ID00012     Titular                      JOSEFA TOMAZ PEREIRA DE SOUZA
# 12     ID00013     Titular                               DAN MARSHALL DA ROLT
# 13     ID00014     Titular                                      NUTRICARE S/A
# 15     ID00016     Titular              ALEXANDRE BARBOSA GONTIJO 86536958691
# 16     ID00017     Titular                                      FUELTECH LTDA

# %% [markdown]
# ## Dicionário de correspondências

# %%
#CRIAR DICIONARIO DE CORRESPONDENCIAS E APLICAR A COLUNA DE NOME DO TITULAR ABREVIADO

correspondencias = {
    ': UNIVERSIDADE FEDERAL DE SANTA MARIA - UFSM' : 'UFSM',
    'A FUNDAÇÃO UNIVERSIDADE FEDERAL DE SÃO CARLOS - UFSCAR' : 'UFSCAR',
    'A UNIVERSIDADE FEDERAL DE GOIÁS - UFG' : 'UFG',
    'CENTRO FEDERAL DE EDUCAÇÃO TECNOLÓGICA CELSO SUCKOW DA FONSECA - CEFET/RJ' : 'CEFET-RJ',
    'CENTRO FEDERAL DE EDUCAÇÃO TECNOLÓGICA DE MINAS GERAIS' : 'CEFET-MG',
    'CENTRO FEDERAL DE EDUCAÇÃO TECNOLÓGICA DE MINAS GERAIS - CEFET/MG' : 'CEFET-MG',
    'CENTRO FEDERAL DE EDUCAÇÃO TECNOLÓGICA DE MINAS GERAIS ? CEFET/MG' : 'CEFET-MG',
    'EMPRESA BRASILEIRA DE SERVIÇOS HOSPITALARES - EBSERH, -FILIAL HOSPITAL UNIVERSITÁRIO PROFESSOR POLYDORO ERNANI DE SÃO THIAGO, DA UNIVERSIDADE FEDERAL DE SANTA CATARINA (HU-UFSC)' : 'UFSC',
    'FUNDACAO UNIVERSIDADE DE BRASILIA' : 'UNB',
    'FUNDAÇÃO UNIVERSIDADE DE BRASILIA' : 'UNB',
    'FUNDAÇÃO UNIVERSIDADE DE BRASÍLIA' : 'UNB',
    'FUNDAÇÃO UNIVERSIDADE DE BRASILIA - FUB' : 'UNB',
    'FUNDAÇÃO UNIVERSIDADE DE BRASÍLIA - FUB' : 'UNB',
    'FUNDAÇÃO UNIVERSIDADE DE BRASÍLIA (FUB)' : 'UNB',
    'FUNDAÇÃO UNIVERSIDADE DE BRASILIA/CENTRO DE APOIO AO DESENVOLVIMENTO TECNOLÓGICO' : 'UNB',
    'FUNDACAO UNIVERSIDADE FEDERAL DE CIENCIAS DA SAUDE DE PORTO ALEGRE' : 'UFCSPA',
    'FUNDAÇÃO UNIVERSIDADE FEDERAL DE MATO GROSSO' : 'UFMT',
    'FUNDACAO UNIVERSIDADE FEDERAL DE MATO GROSSO DO SUL' : 'UFMS',
    'FUNDAÇÃO UNIVERSIDADE FEDERAL DE MATO GROSSO DO SUL' : 'UFMS',
    'FUNDAÇÃO UNIVERSIDADE FEDERAL DE MATO GROSSO DO SUL - (UFMS)' : 'UFMS',
    'FUNDAÇÃO UNIVERSIDADE FEDERAL DE PELOTAS' : 'UFPEL',
    'FUNDAÇÃO UNIVERSIDADE FEDERAL DE PELOTAS - UFPEL' : 'UFPEL',
    'FUNDAÇÃO UNIVERSIDADE FEDERAL DE SÃO CARLOS' : 'UFSCAR',
    'FUNDAÇÃO UNIVERSIDADE FEDERAL DE SÃO CARLOS - UFSCAR' : 'UFSCAR',
    'FUNDAÇÃO UNIVERSIDADE FEDERAL DE SÃO CARLOS ? UFSCAR' : 'UFSCAR',
    'FUNDAÇÃO UNIVERSIDADE FEDERAL DE SÃO CARLOS ? UFSCAR,' : 'UFSCAR',
    'FUNDAÇÃO UNIVERSIDADE FEDERAL DO ABC' : 'UFABC',
    'FUNDAÇÃO UNIVERSIDADE FEDERAL DO ABC - UFABC' : 'UFABC',
    'FUNDAÇÃO UNIVERSIDADE FEDERAL DO ABC- UFABC' : 'UFABC',
    'FUNDAÇÃO UNIVERSIDADE FEDERAL DO ACRE' : 'UFAC',
    'FUNDAÇÃO UNIVERSIDADE FEDERAL DO AMAPÁ' : 'UNIFAP',
    'FUNDAÇÃO UNIVERSIDADE FEDERAL DO MATO GROSSO DO SUL' : 'UFMS',
    'FUNDAÇÃO UNIVERSIDADE FEDERAL DO PAMPA' : 'UNIPAMPA',
    'FUNDAÇÃO UNIVERSIDADE FEDERAL DO PIAUÍ' : 'UFPI',
    'FUNDAÇÃO UNIVERSIDADE FEDERAL DO PIAUÍ - UFPI' : 'UFPI',
    'FUNDAÇÃO UNIVERSIDADE FEDERAL DO RIO GRANDE' : 'FURG',
    'FUNDAÇÃO UNIVERSIDADE FEDERAL DO TOCANTINS' : 'UFT',
    'FUNDACAO UNIVERSIDADE FEDERAL DO VALE DO SAO FRANCISCO' : 'UNIVASF',
    'IFTM - INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DO TRIÂNGULO MINEIRO' : 'IFTM',
    'INSTITUTO FEDERAL CATARINENSE' : 'IFC',
    'INSTITUTO FEDERAL DA PARAÍBA' : 'IFPB',
    'INSTITUTO FEDERAL DE  EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DE MINAS GERAIS' : 'IFMG',
    'INSTITUTO FEDERAL DE ALAGOAS' : 'IFAL',
    'INSTITUTO FEDERAL DE EDUCAÇÃO CIENCIA E TECNOLOGIA DA BAHIA' : 'IFPB',
    'INSTITUTO FEDERAL DE EDUCAÇÃO CIÊNCIA E TECNOLOGIA DA PARAÍBA' : 'IFPB',
    'INSTITUTO FEDERAL DE EDUCAÇÃO CIÊNCIA E TECNOLOGIA DA PARAÍBA - IFPB' : 'IFPB',
    'INSTITUTO FEDERAL DE EDUCAÇÃO CIENCIA E TECNOLOGIA DE MINAS GERAIS' : 'IFMG',
    'INSTITUTO FEDERAL DE EDUCAÇÃO CIÊNCIA E TECNOLOGIA DO AMAPÁ' : 'IFAP',
    'INSTITUTO FEDERAL DE EDUCAÇÃO CIÊNCIA E TECNOLOGIA DO AMAZONAS' : 'IFAM',
    'INSTITUTO FEDERAL DE EDUCAÇÃO CIÊNCIA E TECNOLOGIA DO ESPIRITO SANTO' : 'IFES',
    'INSTITUTO FEDERAL DE EDUCAÇÃO CIÊNCIA E TECNOLOGIA DO ESPÍRITO SANTO' : 'IFES',
    'INSTITUTO FEDERAL DE EDUCAÇÃO CIÊNCIA E TECNOLOGIA DO ESPÍRITO SANTO - IFES' : 'IFES',
    'INSTITUTO FEDERAL DE EDUCAÇÃO CIÊNCIA E TECNOLOGIA DO MARANHÃO' : 'IFMA',
    'INSTITUTO FEDERAL DE EDUCAÇÃO CIÊNCIA E TECNOLOGIA DO MARANHÃO - IFMA' : 'IFMA',
    'INSTITUTO FEDERAL DE EDUCAÇÃO CIÊNCIA E TECNOLOGIA DO PARÁ' : 'IFPA',
    'INSTITUTO FEDERAL DE EDUCAÇÃO CIÊNCIA E TECNOLOGIA DO SERTÃO PERNAMBUCANO' : 'IFSertãoPE',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA' : 'IF',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA  GOIANO' : 'IFGOIANO',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA BAIANO' : 'IFBAIANO',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA BAIANO - IFBAIANO' : 'IFBAIANO',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA CATARINENSE' : 'IFC',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA CATARINENSE (IFC)' : 'IFC',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DA BAHIA' : 'IFBA',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DA BAHIA - IFBA' : 'IFBA',
    'INSTITUTO FEDERAL DE EDUCACAO, CIENCIA E TECNOLOGIA DA PARAIBA' : 'IFPB',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DA PARAÍBA' : 'IFPB',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DA PARAÍBA - CAMPUS CATOLÉ DO ROCHA' : 'IFPB',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DA PARAÍBA - IFPB' : 'IFPB',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DE  PERNAMBUCO (IFPE)' : 'IFPE',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DE ALAGOAS' : 'IFAL',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DE ALAGOAS - IFAL' : 'IFAL',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DE BRASÍLIA' : 'IFDF',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DE GOIÁS' : 'IFG',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DE GOIÁS-IFG' : 'IFG',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DE MATO GROSSO' : 'IFMT',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DE MATO GROSSO DO SUL' : 'IFMS',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DE MINAS GERAIS' : 'IFMG',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DE MINAS GERAIS ? IFMG' : 'IFMG',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DE PERNAMBUCO' : 'IFPE',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DE RONDÔNIA' : 'IFRO',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DE RORAIMA' : 'IFRR',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DE SANTA CATARINA' : 'IFSC',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DE SÃO PAULO' : 'IFSP',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIENCIA E TECNOLOGIA DO  PARÁ' : 'IFPA',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DO CEARÁ' : 'IFCE',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DO CEARÁ - IFCE' : 'IFCE',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DO ESPÍRITO SANTO' : 'IFES',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DO MARANHÃO' : 'IFMA',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DO PARÁ' : 'IFPA',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DO PARANÁ' : 'IFPR',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DO PARANÁ ? IFPR' : 'IFPR',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DO PIAUÍ' : 'IFPI',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DO RIO DE JANEIRO' : 'IFRJ',
    'INSTITUTO FEDERAL DE EDUCACAO, CIÊNCIA E TECNOLOGIA DO RIO DE JANEIRO - IFRJ' : 'IFRJ',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DO RIO DE JANEIRO - IFRJ' : 'IFRJ',
    'INSTITUTO FEDERAL DE EDUCACAO, CIÊNCIA E TECNOLOGIA DO RIO DE JANEIRO - IFRJ,' : 'IFRJ',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DO RIO DE JANEIRO (IFRJ)' : 'IFRJ',
    'INSTITUTO FEDERAL DE EDUCACAO, CIENCIA E TECNOLOGIA DO RIO GRANDE DO NORTE' : 'IFRN',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DO RIO GRANDE DO NORTE' : 'IFRN',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DO RIO GRANDE DO NORTE - IFRN' : 'IFRN',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DO RIO GRANDE DO SUL' : 'IFRS',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DO RIO GRANDE DO SUL - IFRS' : 'IFRS',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DO SERTÃO PERNAMBUCANO' : 'IFSERTAOPE',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DO SUDESTE DE MINAS' : 'IFSEMG',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DO SUL DE MINAS GERAIS - IFSULDEMINAS' : 'IFSULDEMINAS',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DO TOCANTINS' : 'IFTO',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA DO TRIÂNGULO MINEIRO' : 'IFTM',
    'INSTITUTO FEDERAL DE EDUCACAO, CIENCIA E TECNOLOGIA FARROUPILHA' : 'IFFARROUPILHA',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA FLUMINENSE' : 'IFFLUMINENSE',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA FLUMINENSE - IFFLUMINENSE' : 'IFFLUMINENSE',
    'INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA GOIANO' : 'IFGOIANO',
    'INSTITUTO FEDERAL DE EDUCAÇÃO,CIÊNCIA E TECNOLOGIA DA PARAÍBA' : 'IFPB',
    'INSTITUTO FEDERAL DE EDUCAÇÃO,CIENCIA E TECNOLOGIA DO ACRE' : 'IFAC',
    'INSTITUTO FEDERAL DE EDUCAÇÃO,CIÊNCIA E TECNOLOGIA DO PARÁ' : 'IFPA',
    'INSTITUTO FEDERAL DE MATO GROSSO - IFMT' : 'IFMT',
    'INSTITUTO FEDERAL DE SANTA CATARINA' : 'IFSC',
    'INSTITUTO FEDERAL DO NORTE DE MINAS GERAIS' : 'IFNORTEDEMINAS',
    'INSTITUTO FEDERAL DO PARANÁ' : 'IFPR',
    'INSTITUTO FEDERAL DO PARANÁ - IFPR' : 'IFPR',
    'INSTITUTO FEDERAL DO RIO GRANDE DO NORTE' : 'IFRN',
    'INSTITUTO FEDERAL DO TOCANTINS' : 'IFTO',
    'INSTITUTO FEDERAL FARROUPILHA - IFFAR' : 'IFFAR',
    'INSTITUTO FEDERAL SUL-RIO-GRANDENSE' : 'IFSUL',
    'UFPA - UNIVERSIDADE FEDERAL DO PARÁ' : 'UFPA',
    'UNIFEI - UNIVERSIDADE FEDERAL DE ITAJUBÁ' : 'UNIFEI',
    'UNIVERSIDADE  FEDERAL DE OURO PRETO - UFOP' : 'UFOP',
    'UNIVERSIDADE DA INTEGRAÇÃO INTERNACIONAL DA LUSOFONIA AFRO-BRASILEIRA - UNILAB' : 'UNILAB',
    'UNIVERSIDADE DA INTEGRAÇÃO INTERNACIONAL DA LUSOFONIA AFRO-BRASILEIRA (UNILAB)' : 'UNILAB',
    'UNIVERSIDADE DE BRASÍLIA' : 'UNB',
    'UNIVERSIDADE DE BRASILIA - UNB' : 'UNB',
    'UNIVERSIDADE FEDEERAL DE SANTA MARIA - UFSM' : 'UFSM',
    'UNIVERSIDADE FEDERAL 00 RIO DE JANEIRO -UFRJ' : 'UFRJ',
    'UNIVERSIDADE FEDERAL DA BAHIA' : 'UFBA',
    'UNIVERSIDADE FEDERAL DA BAHIA - UFBA' : 'UFBA',
    'UNIVERSIDADE FEDERAL DA FRONTEIRA SUL, UFFS' : 'UFFS',
    'UNIVERSIDADE FEDERAL DA GRANDE DOURADOS' : 'UFGD',
    'UNIVERSIDADE FEDERAL DA GRANDE DOURADOS - UFGD' : 'UFGD',
    'UNIVERSIDADE FEDERAL DA INTEGRAÇÃO  LATINO-AMERICANA - UNILA' : 'UNILA',
    'UNIVERSIDADE FEDERAL DA INTEGRAÇÃO LATINO-AMERICANA' : 'UNILA',
    'UNIVERSIDADE FEDERAL DA INTEGRAÇÃO LATINOAMERICANA - UNILA' : 'UNILA',
    'UNIVERSIDADE FEDERAL DA INTEGRAÇÃO LATINO-AMERICANA - UNILA' : 'UNILA',
    'UNIVERSIDADE FEDERAL DA PARAIBA' : 'UFPB',
    'UNIVERSIDADE FEDERAL DA PARAÍBA' : 'UFPB',
    'UNIVERSIDADE FEDERAL DA PARAIBA - UFPB' : 'UFPB',
    'UNIVERSIDADE FEDERAL DA PARAÍBA - UFPB' : 'UFPB',
    'UNIVERSIDADE FEDERAL DE  ALFENAS - UNIFAL-MG' : 'UNIFAL-MG',
    'UNIVERSIDADE FEDERAL DE  LAVRAS - UFLA' : 'UFLA',
    'UNIVERSIDADE FEDERAL DE  SÃO JOÃO DEL REI - UFSJ' : 'UFSJ',
    'UNIVERSIDADE FEDERAL DE ALAGOAS' : 'UFAL',
    'UNIVERSIDADE FEDERAL DE ALAGOAS - UFAL' : 'UFAL',
    'UNIVERSIDADE FEDERAL DE ALFENAS' : 'UNIFAL-MG',
    'UNIVERSIDADE FEDERAL DE ALFENAS - UNIFAL' : 'UNIFAL-MG',
    'UNIVERSIDADE FEDERAL DE ALFENAS - UNIFAL-MG' : 'UNIFAL-MG',
    'UNIVERSIDADE FEDERAL DE ALFENAS -UNIFAL' : 'UNIFAL-MG',
    'UNIVERSIDADE FEDERAL DE CAMPINA GRANDE' : 'UFCG',
    'UNIVERSIDADE FEDERAL DE CAMPINA GRANDE - PB' : 'UFCG',
    'UNIVERSIDADE FEDERAL DE CAMPINA GRANDE - UFCG' : 'UFCG',
    'UNIVERSIDADE FEDERAL DE CAMPINA GRANDE (UFCG)' : 'UFCG',
    'UNIVERSIDADE FEDERAL DE GOIAS' : 'UFG',
    'UNIVERSIDADE FEDERAL DE GOIÁS' : 'UFG',
    'UNIVERSIDADE FEDERAL DE GOIÁS - UFG' : 'UFG',
    'UNIVERSIDADE FEDERAL DE GOIÁS-UFG' : 'UFG',
    'UNIVERSIDADE FEDERAL DE ITAJUBÁ' : 'UNIFEI',
    'UNIVERSIDADE FEDERAL DE ITAJUBÁ - UNIFEI' : 'UNIFEI',
    'UNIVERSIDADE FEDERAL DE ITAJUBA- UNIFEI' : 'UNIFEI',
    'UNIVERSIDADE FEDERAL DE JATAI' : 'UFJ',
    'UNIVERSIDADE FEDERAL DE JUIZ  DE FORA - UFJF' : 'UFJF',
    'UNIVERSIDADE FEDERAL DE JUIZ DE FORA' : 'UFJF',
    'UNIVERSIDADE FEDERAL DE JUIZ DE FORA - UFJF' : 'UFJF',
    'UNIVERSIDADE FEDERAL DE LAVRAS' : 'UFLA',
    'UNIVERSIDADE FEDERAL DE LAVRAS - UFLA' : 'UFLA',
    'UNIVERSIDADE FEDERAL DE LAVRAS,UNIVERSIDADE FEDERAL DE LAVRAS - UFLA' : 'UFLA',
    'UNIVERSIDADE FEDERAL DE MATO GROSSO' : 'UFMT',
    'UNIVERSIDADE FEDERAL DE MATO GROSSO DO SUL' : 'UFMS',
    'UNIVERSIDADE FEDERAL DE MINAS GERAIS' : 'UFMG',
    'UNIVERSIDADE FEDERAL DE MINAS GERAIS - UFMG' : 'UFMG',
    'UNIVERSIDADE FEDERAL DE MINAS GERAIS ? UFMG' : 'UFMG',
    'UNIVERSIDADE FEDERAL DE MINAS GERAIS-UFMG' : 'UFMG',
    'UNIVERSIDADE FEDERAL DE OURO PRETO' : 'UFOP',
    'UNIVERSIDADE FEDERAL DE OURO PRETO  - UFOP' : 'UFOP',
    'UNIVERSIDADE FEDERAL DE OURO PRETO - UFOP' : 'UFOP',
    'UNIVERSIDADE FEDERAL DE OURO PRETO ? UFOP' : 'UFOP',
    'UNIVERSIDADE FEDERAL DE PELOTAS' : 'UFPEL',
    'UNIVERSIDADE FEDERAL DE PERNAMBUCO' : 'UFPE',
    'UNIVERSIDADE FEDERAL DE PERNAMBUCO - UFPE' : 'UFPE',
    'UNIVERSIDADE FEDERAL DE PERNAMBUCO -UFPE' : 'UFPE',
    'UNIVERSIDADE FEDERAL DE RONDONOPOLIS' : 'UFR',
    'UNIVERSIDADE FEDERAL DE RORAIMA' : 'UFRR',
    'UNIVERSIDADE FEDERAL DE SANTA CATARINA' : 'UFSC',
    'Universidade Federal de Santa Catarina' : 'UFSC',
    'UNIVERSIDADE FEDERAL DE SANTA CATARINA - UFSC' : 'UFSC',
    'UNIVERSIDADE FEDERAL DE SANTA MARIA' : 'UFSM',
    'UNIVERSIDADE FEDERAL DE SANTA MARIA - UFSM' : 'UFSM',
    'UNIVERSIDADE FEDERAL DE SANTA MARIA ? UFSM' : 'UFSM',
    'UNIVERSIDADE FEDERAL DE SÃO  JOÃO DEL REI - UFSJ' : 'UFSJ',
    'UNIVERSIDADE FEDERAL DE SÃO  JOÃO DEL-REI - UFSJ' : 'UFSJ',
    'UNIVERSIDADE FEDERAL DE SÃO JOÃO DEL REI' : 'UFSJ',
    'UNIVERSIDADE FEDERAL DE SÃO JOÃO DEL REI - UFSJ' : 'UFSJ',
    'UNIVERSIDADE FEDERAL DE SÃO JOÃO DEL-REI' : 'UFSJ',
    'UNIVERSIDADE FEDERAL DE SÃO JOÃO DEL-REI  UFSJ' : 'UFSJ',
    'UNIVERSIDADE FEDERAL DE SÃO JOÃO DEL-REI - UFSJ' : 'UFSJ',
    'UNIVERSIDADE FEDERAL DE SÃO PAULO' : 'UNIFESP',
    'UNIVERSIDADE FEDERAL DE SÃO PAULO - UNIFESP' : 'UNIFESP',
    'UNIVERSIDADE FEDERAL DE SERGIPE' : 'UFS',
    'UNIVERSIDADE FEDERAL DE UBERLANDIA' : 'UFU',
    'UNIVERSIDADE FEDERAL DE UBERLÂNDIA' : 'UFU',
    'UNIVERSIDADE FEDERAL DE UBERLANDIA - UFU' : 'UFU',
    'UNIVERSIDADE FEDERAL DE UBERLÂNDIA - UFU' : 'UFU',
    'UNIVERSIDADE FEDERAL DE UBERLÂNDIA – UFU' : 'UFU',
    'UNIVERSIDADE FEDERAL DE UBERLÂNDIA ? UFU' : 'UFU',
    'UNIVERSIDADE FEDERAL DE UBERLÂNDIA-UFU' : 'UFU',
    'UNIVERSIDADE FEDERAL DE VIÇOSA' : 'UFV',
    'UNIVERSIDADE FEDERAL DE VIÇOSA - UFV' : 'UFV',
    'UNIVERSIDADE FEDERAL DE VIÇOSA-UFV' : 'UFV',
    'UNIVERSIDADE FEDERAL DO ABC' : 'UFABC',
    'UNIVERSIDADE FEDERAL DO AGRESTE DE PERNAMBUCO' : 'UFAPE',
    'UNIVERSIDADE FEDERAL DO AMAPA' : 'UNIFAP',
    'UNIVERSIDADE FEDERAL DO AMAPÁ' : 'UNIFAP',
    'UNIVERSIDADE FEDERAL DO AMAZONAS' : 'UFAM',
    'UNIVERSIDADE FEDERAL DO CARIRI (UFCA)' : 'UFCA',
    'UNIVERSIDADE FEDERAL DO CEARA' : 'UFC',
    'UNIVERSIDADE FEDERAL DO CEARÁ' : 'UFC',
    'UNIVERSIDADE FEDERAL DO CEARÁ - UFC' : 'UFC',
    'UNIVERSIDADE FEDERAL DO CEARÁ – UFC' : 'UFC',
    'UNIVERSIDADE FEDERAL DO DELTA DO PARNAÍBA - UFDPAR' : 'UFDPAR',
    'UNIVERSIDADE FEDERAL DO ESPIRITO SANTO' : 'UFES',
    'UNIVERSIDADE FEDERAL DO ESPÍRITO SANTO' : 'UFES',
    'UNIVERSIDADE FEDERAL DO ESPIRÍTO SANTO - UFES' : 'UFES',
    'UNIVERSIDADE FEDERAL DO ESPÍRITO SANTO - UFES' : 'UFES',
    'UNIVERSIDADE FEDERAL DO ESTADO DO RIO DE JANEIRO' : 'UNIRIO',
    'UNIVERSIDADE FEDERAL DO ESTADO DO RIO DE JANEIRO - UFRJ' : 'UNIRIO',
    'UNIVERSIDADE FEDERAL DO MARANHÃO' : 'UFMA',
    'UNIVERSIDADE FEDERAL DO MARANHÃO-UFMA' : 'UFMA',
    'UNIVERSIDADE FEDERAL DO MATO GROSSO' : 'UFMT',
    'UNIVERSIDADE FEDERAL DO OESTE DO PARÁ' : 'UFOPA',
    'UNIVERSIDADE FEDERAL DO PAMPA' : 'UNIPAMPA',
    'UNIVERSIDADE FEDERAL DO PARÁ' : 'UFPA',
    'UNIVERSIDADE FEDERAL DO PARÁ - UFPA' : 'UFPA',
    'UNIVERSIDADE FEDERAL DO PARANA' : 'UFPR',
    'UNIVERSIDADE FEDERAL DO PARANÁ' : 'UFPR',
    'UNIVERSIDADE FEDERAL DO PARANÁ - UFPR' : 'UFPR',
    'UNIVERSIDADE FEDERAL DO PIAUÍ' : 'UFPI',
    'Universidade Federal do Piauí' : 'UFPI',
    'UNIVERSIDADE FEDERAL DO PIAUÍ  UFPI' : 'UFPI',
    'UNIVERSIDADE FEDERAL DO PIAUÍ - UFPI' : 'UFPI',
    'UNIVERSIDADE FEDERAL DO PIAUÍ- UFPI' : 'UFPI',
    'UNIVERSIDADE FEDERAL DO RECÔNCAVO DA BAHIA' : 'UFRB',
    'UNIVERSIDADE FEDERAL DO RECONCAVO DA BAHIA - UFRB' : 'UFRB',
    'UNIVERSIDADE FEDERAL DO RECÔNCAVO DA BAHIA - UFRB' : 'UFRB',
    'UNIVERSIDADE FEDERAL DO RIO DE JANEIRO' : 'UFRJ',
    'UNIVERSIDADE FEDERAL DO RIO DE JANEIRO - UFRJ' : 'UFRJ',
    'UNIVERSIDADE FEDERAL DO RIO DE JANEIRO ? UFRJ' : 'UFRJ',
    'UNIVERSIDADE FEDERAL DO RIO DE JANEIRO _ UFRJ' : 'UFRJ',
    'UNIVERSIDADE FEDERAL DO RIO DE JANEIRO -UFRJ' : 'UFRJ',
    'UNIVERSIDADE FEDERAL DO RIO GRANDE - FURG' : 'FURG',
    'UNIVERSIDADE FEDERAL DO RIO GRANDE DO NORTE' : 'UFRN',
    'UNIVERSIDADE FEDERAL DO RIO GRANDE DO NORTE - UFRN' : 'UFRN',
    'UNIVERSIDADE FEDERAL DO RIO GRANDE DO SUL' : 'UFRGS',
    'UNIVERSIDADE FEDERAL DO RIO GRANDE DO SUL - UFRGS' : 'UFRGS',
    'UNIVERSIDADE FEDERAL DO SUL DA BAHIA' : 'UFSB',
    'UNIVERSIDADE FEDERAL DO SUL DA BAHIA - UFSB' : 'UFSB',
    'UNIVERSIDADE FEDERAL DO SUL E SUDESTE DO PARÁ' : 'UNIFESSPA',
    'UNIVERSIDADE FEDERAL DO TOCANTINS' : 'UFT',
    'UNIVERSIDADE FEDERAL DO TOCANTINS - UFT' : 'UFT',
    'UNIVERSIDADE FEDERAL DO TRIÂNGULO MINEIRO' : 'UFTM',
    'UNIVERSIDADE FEDERAL DO TRIÂNGULO MINEIRO - UFTM' : 'UFTM',
    'UNIVERSIDADE FEDERAL DO TRIÂNGULO MINEIRO-UFTM' : 'UFTM',
    'UNIVERSIDADE FEDERAL DO VALE DO SÃO FRANCISCO' : 'UNIVASF',
    'UNIVERSIDADE FEDERAL DO VALE DO SÃO FRANCISCO - UNIVASF' : 'UNIVASF',
    'UNIVERSIDADE FEDERAL DOS VALES DO JEQUITINHONHA E MUCURI' : 'UFVJM',
    'UNIVERSIDADE FEDERAL DOS VALES DO JEQUITINHONHA E MUCURI - UFVJM' : 'UFVJM',
    'UNIVERSIDADE FEDERAL DOS VALES DO JEQUITINHONHA E MUCURI- UFVJM' : 'UFVJM',
    'UNIVERSIDADE FEDERAL FLUMINENSE' : 'UFF',
    'UNIVERSIDADE FEDERAL FLUMINENSE - UFF' : 'UFF',
    'UNIVERSIDADE FEDERAL RURAL DA AMAZÔNIA' : 'UFRA',
    'UNIVERSIDADE FEDERAL RURAL DE PARNANBUCO - UFRPE' : 'UFRPE',
    'UNIVERSIDADE FEDERAL RURAL DE PERNAMBUCO' : 'UFRPE',
    'UNIVERSIDADE FEDERAL RURAL DE PERNAMBUCO - UFRPE' : 'UFRPE',
    'UNIVERSIDADE FEDERAL RURAL DE PERNAMBUCO (UFRPE)' : 'UFRPE',
    'UNIVERSIDADE FEDERAL RURAL DO RIO DE JANEIRO' : 'UFRRJ',
    'UNIVERSIDADE FEDERAL RURAL DO RIO DE JANEIRO-UFRRJ' : 'UFRRJ',
    'UNIVERSIDADE FEDERAL RURAL DO SEMI-ÁRIDO' : 'UFERSA',
    'UNIVERSIDADE FEDERAL RURAL DO SEMI-ARIDO - UFERSA' : 'UFERSA',
    'UNIVERSIDADE TECNÓLICA FEDERAL DO PARANÁ - UTFPR' : 'UTFPR',
    'UNIVERSIDADE TECNOLOGICA FEDERAL DO PARANA' : 'UTFPR',
    'UNIVERSIDADE TECNOLÓGICA FEDERAL DO PARANÁ' : 'UTFPR',
    'UNIVERSIDADE TECNOLÓGICA FEDERAL DO PARANÁ - UTFPR' : 'UTFPR',
    'UNIVERSIDADE TECNOLÓGICA FEDERAL DO PARANÁ - UTFPR-PATO BRANCO' : 'UTFPR',
    'UTFPR - UNIVERSIDADE TECNOLÓGICA FEDERAL DO PARANÁ' : 'UTFPR'
}

# %%
#CRIAR NOVA COLUNA COPIANDO A COLUNA DO NOME DO TITULAR PARA ABREVIAR/AGRUPAR
federais_melted['ifes_abrev'] = federais_melted['responsavel'].copy()
federais_melted['ifes_abrev'] = federais_melted['ifes_abrev'].map(correspondencias)
federais_melted = federais_melted.drop('responsavel',axis=1)
federais_melted.head()
# Out:
#             ID    parceria ifes ifes_abrev
# 2      ID00003     Titular  Sim        UFC
# 24724  ID00011  Parceiro01  Sim       UFPE
# 10     ID00011     Titular  Sim       IFPE
# 14     ID00015     Titular  Sim   IFGOIANO
# 23     ID00024     Titular  Sim        UFU

# %%
federais_largo = federais_melted[['ID', 'ifes', 'ifes_abrev']]
federais_largo = federais_largo.sort_values(by='ID', ascending=True).drop_duplicates()
federais_largo.head()
# Out:
#             ID ifes ifes_abrev
# 2      ID00003  Sim        UFC
# 24724  ID00011  Sim       UFPE
# 10     ID00011  Sim       IFPE
# 14     ID00015  Sim   IFGOIANO
# 23     ID00024  Sim        UFU

# %%
data_patentes_largo = data_largo.merge(federais_largo, on='ID', how='left')
data_patentes_largo['ifes'] = data_patentes_largo['ifes'].fillna('Não', inplace=False)
data_patentes_largo.head()
# Out:
#         ID data_publicacao diretoria  numero_revista  codigo  \
# 0  ID00001      07/01/2020   Patente            2557     3.1
# 1  ID00002      07/01/2020   Patente            2557     3.1
# 2  ID00003      07/01/2020   Patente            2557     3.1
# 3  ID00004      07/01/2020   Patente            2557     3.1
# 4  ID00005      07/01/2020   Patente            2557     3.1
#
#                                               titulo               numero  \
# 0  Publicação do Pedido de Patente ou de Certific...  BR 10 2013 016644-8
# 1  Publicação do Pedido de Patente ou de Certific...  BR 10 2014 001105-6
# 2  Publicação do Pedido de Patente ou de Certific...  BR 10 2017 004929-9
# 3  Publicação do Pedido de Patente ou de Certific...  BR 10 2017 024659-0
# 4  Publicação do Pedido de Patente ou de Certific...  BR 10 2017 026178-6
#
#   data_deposito data_prioridade cod_prioridade  ... Parceiro28 Parceiro29  \
# 0    27/06/2013             NaN            NaN  ...        NaN        NaN
# 1    16/01/2014      18/01/2013    TW102201214  ...        NaN        NaN
# 2    13/03/2017             NaN            NaN  ...        NaN        NaN
# 3    17/11/2017             NaN            NaN  ...        NaN        NaN
# 4    05/12/2017             NaN            NaN  ...        NaN        NaN
#
#   Parceiro30 Parceiro31 Parceiro32 Parceiro33 Parceiro34  \
# 0        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN
#
#                              Titular ifes ifes_abrev
# 0            ACM EL ORRA COLCHÕES ME  Não        NaN
# 1        KEYARROW (TAIWAN) CO., LTD.  Não        NaN
# 2      UNIVERSIDADE FEDERAL DO CEARÁ  Sim        UFC
# 3              CID GRANJA DOS SANTOS  Não        NaN
# 4  FUNDAÇÃO UNIVERSIDADE DO AMAZONAS  Não        NaN
#
# [5 rows x 54 columns]

# %%
data_patentes_largo_ifes = data_patentes_largo[data_patentes_largo['ifes'] == 'Sim']
data_patentes_largo_ifes.head()
# Out:
#          ID data_publicacao diretoria  numero_revista  codigo  \
# 2   ID00003      07/01/2020   Patente            2557     3.1
# 10  ID00011      07/01/2020   Patente            2557     3.1
# 11  ID00011      07/01/2020   Patente            2557     3.1
# 15  ID00015      07/01/2020   Patente            2557     3.1
# 24  ID00024      07/01/2020   Patente            2557     3.1
#
#                                                titulo               numero  \
# 2   Publicação do Pedido de Patente ou de Certific...  BR 10 2017 004929-9
# 10  Publicação do Pedido de Patente ou de Certific...  BR 10 2018 012005-0
# 11  Publicação do Pedido de Patente ou de Certific...  BR 10 2018 012005-0
# 15  Publicação do Pedido de Patente ou de Certific...  BR 10 2018 012049-2
# 24  Publicação do Pedido de Patente ou de Certific...  BR 10 2018 012161-8
#
#    data_deposito data_prioridade cod_prioridade  ... Parceiro28 Parceiro29  \
# 2     13/03/2017             NaN            NaN  ...        NaN        NaN
# 10    13/06/2018             NaN            NaN  ...        NaN        NaN
# 11    13/06/2018             NaN            NaN  ...        NaN        NaN
# 15    14/06/2018             NaN            NaN  ...        NaN        NaN
# 24    14/06/2018             NaN            NaN  ...        NaN        NaN
#
#    Parceiro30 Parceiro31 Parceiro32 Parceiro33 Parceiro34  \
# 2         NaN        NaN        NaN        NaN        NaN
# 10        NaN        NaN        NaN        NaN        NaN
# 11        NaN        NaN        NaN        NaN        NaN
# 15        NaN        NaN        NaN        NaN        NaN
# 24        NaN        NaN        NaN        NaN        NaN
#
#                                               Titular ifes ifes_abrev
# 2                       UNIVERSIDADE FEDERAL DO CEARÁ  Sim        UFC
# 10  INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNO...  Sim       UFPE
# 11  INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNO...  Sim       IFPE
# 15  INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNO...  Sim   IFGOIANO
# 24                 UNIVERSIDADE FEDERAL DE UBERLÂNDIA  Sim        UFU
#
# [5 rows x 54 columns]

# %%
aux1 = data_melted.copy()
aux1.head(12)
# Out:
#             ID    parceria                                        responsavel
# 0      ID00001     Titular                            ACM EL ORRA COLCHÕES ME
# 1      ID00002     Titular                        KEYARROW (TAIWAN) CO., LTD.
# 2      ID00003     Titular                      UNIVERSIDADE FEDERAL DO CEARÁ
# 3      ID00004     Titular                              CID GRANJA DOS SANTOS
# 4      ID00005     Titular                  FUNDAÇÃO UNIVERSIDADE DO AMAZONAS
# 5      ID00006     Titular  MISSÃO SALESIANA DE MATO GROSSO UNIVERSIDADE C...
# 6      ID00007     Titular                                      GRENDENE S.A.
# 7      ID00008     Titular                                    RENTBRELLA S.A.
# 8      ID00009     Titular   FUNDAÇÃO UNIVERSIDADE ESTADUAL DO CEARÁ - FUNECE
# 9      ID00010     Titular                         MARCUS CEZAR KLAUTAU BONNA
# 24724  ID00011  Parceiro01                 UNIVERSIDADE FEDERAL DE PERNAMBUCO
# 10     ID00011     Titular  INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNO...

# %%
aux2 = federais_melted.copy()
aux2.head()
# Out:
#             ID    parceria ifes ifes_abrev
# 2      ID00003     Titular  Sim        UFC
# 24724  ID00011  Parceiro01  Sim       UFPE
# 10     ID00011     Titular  Sim       IFPE
# 14     ID00015     Titular  Sim   IFGOIANO
# 23     ID00024     Titular  Sim        UFU

# %%
aux3 = aux1.merge(aux2, on=['ID', 'parceria'], how='left')
aux3['ifes'] = aux3['ifes'].fillna('Não', inplace=False)
aux3.head(12)
# Out:
#          ID    parceria                                        responsavel  \
# 0   ID00001     Titular                            ACM EL ORRA COLCHÕES ME
# 1   ID00002     Titular                        KEYARROW (TAIWAN) CO., LTD.
# 2   ID00003     Titular                      UNIVERSIDADE FEDERAL DO CEARÁ
# 3   ID00004     Titular                              CID GRANJA DOS SANTOS
# 4   ID00005     Titular                  FUNDAÇÃO UNIVERSIDADE DO AMAZONAS
# 5   ID00006     Titular  MISSÃO SALESIANA DE MATO GROSSO UNIVERSIDADE C...
# 6   ID00007     Titular                                      GRENDENE S.A.
# 7   ID00008     Titular                                    RENTBRELLA S.A.
# 8   ID00009     Titular   FUNDAÇÃO UNIVERSIDADE ESTADUAL DO CEARÁ - FUNECE
# 9   ID00010     Titular                         MARCUS CEZAR KLAUTAU BONNA
# 10  ID00011  Parceiro01                 UNIVERSIDADE FEDERAL DE PERNAMBUCO
# 11  ID00011     Titular  INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNO...
#
#    ifes ifes_abrev
# 0   Não        NaN
# 1   Não        NaN
# 2   Sim        UFC
# 3   Não        NaN
# 4   Não        NaN
# 5   Não        NaN
# 6   Não        NaN
# 7   Não        NaN
# 8   Não        NaN
# 9   Não        NaN
# 10  Sim       UFPE
# 11  Sim       IFPE

# %%
data_patentes_longo = data.merge(aux3, on='ID', how='outer')
data_patentes_longo['parceria'] = data_patentes_longo['parceria'].map(lambda x : 'Parceiro' if x.startswith('Parc') else x)
data_patentes_longo.head(12)
# Out:
#          ID data_publicacao diretoria  numero_revista  codigo  \
# 0   ID00001      07/01/2020   Patente            2557     3.1
# 1   ID00002      07/01/2020   Patente            2557     3.1
# 2   ID00003      07/01/2020   Patente            2557     3.1
# 3   ID00004      07/01/2020   Patente            2557     3.1
# 4   ID00005      07/01/2020   Patente            2557     3.1
# 5   ID00006      07/01/2020   Patente            2557     3.1
# 6   ID00007      07/01/2020   Patente            2557     3.1
# 7   ID00008      07/01/2020   Patente            2557     3.1
# 8   ID00009      07/01/2020   Patente            2557     3.1
# 9   ID00010      07/01/2020   Patente            2557     3.1
# 10  ID00011      07/01/2020   Patente            2557     3.1
# 11  ID00011      07/01/2020   Patente            2557     3.1
#
#                                                titulo               numero  \
# 0   Publicação do Pedido de Patente ou de Certific...  BR 10 2013 016644-8
# 1   Publicação do Pedido de Patente ou de Certific...  BR 10 2014 001105-6
# 2   Publicação do Pedido de Patente ou de Certific...  BR 10 2017 004929-9
# 3   Publicação do Pedido de Patente ou de Certific...  BR 10 2017 024659-0
# 4   Publicação do Pedido de Patente ou de Certific...  BR 10 2017 026178-6
# 5   Publicação do Pedido de Patente ou de Certific...  BR 10 2017 027316-4
# 6   Publicação do Pedido de Patente ou de Certific...  BR 10 2018 001913-9
# 7   Publicação do Pedido de Patente ou de Certific...  BR 10 2018 009789-0
# 8   Publicação do Pedido de Patente ou de Certific...  BR 10 2018 009796-2
# 9   Publicação do Pedido de Patente ou de Certific...  BR 10 2018 011938-9
# 10  Publicação do Pedido de Patente ou de Certific...  BR 10 2018 012005-0
# 11  Publicação do Pedido de Patente ou de Certific...  BR 10 2018 012005-0
#
#    data_deposito data_prioridade cod_prioridade  ...  \
# 0     27/06/2013             NaN            NaN  ...
# 1     16/01/2014      18/01/2013    TW102201214  ...
# 2     13/03/2017             NaN            NaN  ...
# 3     17/11/2017             NaN            NaN  ...
# 4     05/12/2017             NaN            NaN  ...
# 5     06/12/2017             NaN            NaN  ...
# 6     29/01/2018             NaN            NaN  ...
# 7     15/05/2018             NaN            NaN  ...
# 8     15/05/2018             NaN            NaN  ...
# 9     13/06/2018             NaN            NaN  ...
# 10    13/06/2018             NaN            NaN  ...
# 11    13/06/2018             NaN            NaN  ...
#
#                                        classif_nacion  \
# 0                              B29B 17/00; B29C 43/00
# 1                             F16C 11/04; E05F 1/1215
# 2                             H01Q 13/106; H01Q 1/241
# 3                                G01F 1/58; H04W 4/12
# 4             H04L 67/42; H04L 61/1558; H04L 29/12141
# 5   A23L 29/231; A23L 2/04; A23L 19/00; C08B 37/00...
# 6   C08G 18/4277; C08K 2003/0856; C08K 3/10; A43C ...
# 7   G06Q 30/00; G06F 3/04842; G06Q 10/08; G07C 9/0...
# 8                                                 NaN
# 9                  H04M 1/20; H04B 1/3888; H04M 1/035
# 10                                          G01D 3/08
# 11                                          G01D 3/08
#
#                                           titulo_inid  \
# 0   APERFEIÇOAMENTO INTRODUZIDO EM PROCESSO DE REC...
# 1         DOBRADIÇA PARA CONJUNTO DE CAPAS PROTETORAS
# 2   UMA NOVA ANTENA DE MICROFITA TRI-BANDA, DE TAM...
# 3   DISPOSITIVO DE MÚLTIPLOS MÓDULOS COM OTIMIZAÇÃ...
# 4   BEHAVIOR DEFINITION MODEL FOR INTERNET OF THIN...
# 5   MÉTODO DE EXTRAÇÃO DA PECTINA ADAPTADA PARA SE...
# 6   COMPÓSITO INDUTÍVEL ELETROMAGNETICAMENTE CONTE...
# 7    MÁQUINA DE COMPARTILHAMENTO E ALUGUEL DE OBJETOS
# 8   DESENVOLVIMENTO DE PRODUTOS  FITOTERÁPICOS  AD...
# 9   ESTÚDIO PORTÁTIL COM ISOLAMENTO ACÚSTICO PARA ...
# 10  METODOLOGIA PARA O MONITORAMENTO DA ESTABILIDA...
# 11  METODOLOGIA PARA O MONITORAMENTO DA ESTABILIDA...
#
#                                          titular_nome  titular_uf  \
# 0                             ACM EL ORRA COLCHÕES ME          SP
# 1                         KEYARROW (TAIWAN) CO., LTD.         NaN
# 2                       UNIVERSIDADE FEDERAL DO CEARÁ          CE
# 3                               CID GRANJA DOS SANTOS         NaN
# 4                   FUNDAÇÃO UNIVERSIDADE DO AMAZONAS          AM
# 5   MISSÃO SALESIANA DE MATO GROSSO UNIVERSIDADE C...          MS
# 6                                       GRENDENE S.A.          CE
# 7                                     RENTBRELLA S.A.          SP
# 8    FUNDAÇÃO UNIVERSIDADE ESTADUAL DO CEARÁ - FUNECE          CE
# 9                          MARCUS CEZAR KLAUTAU BONNA          SP
# 10  INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNO...  PE; PE; PE
# 11  INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNO...  PE; PE; PE
#
#    titular_pais                                      inventor_nome  parceria  \
# 0            BR                         ABDO CARIM MOUMTEZ EL ORRA   Titular
# 1            TW                           FU-YI CHEN; CHI, LI-LING   Titular
# 2            BR  ANTONIO SERGIO BEZERRA SOMBRA; RONALDO GLAUBER...   Titular
# 3            BR                              CID GRANJA DOS SANTOS   Titular
# 4            BR  EDUARDO JAMES PEREIRA SOUTO; NAMEDIN PEREIRA T...   Titular
# 5            BR   MARNEY PASCOLI CEREDA; CAROLLAYNE SANTANA JÁCOMO   Titular
# 6            BR           EDUARDO RADAELLI PASQUAL; MAICON ZANOTTO   Titular
# 7            BR  Sigilo de Autor, conforme solicitado e com bas...   Titular
# 8            BR  JOSÉ CLAUDIO CARNEIRO DE FREITAS; ICARO GUSMÃO...   Titular
# 9            BR                         MARCUS CEZAR KLAUTAU BONNA   Titular
# 10   BR; BR; BR  JOSÉ EDUARDO FERREIRA DE OLIVEIRA; NELSON GONÇ...  Parceiro
# 11   BR; BR; BR  JOSÉ EDUARDO FERREIRA DE OLIVEIRA; NELSON GONÇ...   Titular
#
#                                           responsavel ifes ifes_abrev
# 0                             ACM EL ORRA COLCHÕES ME  Não        NaN
# 1                         KEYARROW (TAIWAN) CO., LTD.  Não        NaN
# 2                       UNIVERSIDADE FEDERAL DO CEARÁ  Sim        UFC
# 3                               CID GRANJA DOS SANTOS  Não        NaN
# 4                   FUNDAÇÃO UNIVERSIDADE DO AMAZONAS  Não        NaN
# 5   MISSÃO SALESIANA DE MATO GROSSO UNIVERSIDADE C...  Não        NaN
# 6                                       GRENDENE S.A.  Não        NaN
# 7                                     RENTBRELLA S.A.  Não        NaN
# 8    FUNDAÇÃO UNIVERSIDADE ESTADUAL DO CEARÁ - FUNECE  Não        NaN
# 9                          MARCUS CEZAR KLAUTAU BONNA  Não        NaN
# 10                 UNIVERSIDADE FEDERAL DE PERNAMBUCO  Sim       UFPE
# 11  INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNO...  Sim       IFPE
#
# [12 rows x 21 columns]

# %%
data_patentes_longo_ifes = data_patentes_longo[data_patentes_longo['ifes'] == 'Sim']
data_patentes_longo_ifes.head(12)
# Out:
#          ID data_publicacao diretoria  numero_revista  codigo  \
# 2   ID00003      07/01/2020   Patente            2557     3.1
# 10  ID00011      07/01/2020   Patente            2557     3.1
# 11  ID00011      07/01/2020   Patente            2557     3.1
# 16  ID00015      07/01/2020   Patente            2557     3.1
# 26  ID00024      07/01/2020   Patente            2557     3.1
# 28  ID00026      07/01/2020   Patente            2557     3.1
# 32  ID00030      07/01/2020   Patente            2557     3.1
# 34  ID00031      07/01/2020   Patente            2557     3.1
# 39  ID00035      07/01/2020   Patente            2557     3.1
# 40  ID00036      07/01/2020   Patente            2557     3.1
# 43  ID00039      07/01/2020   Patente            2557     3.1
# 56  ID00050      07/01/2020   Patente            2557     3.1
#
#                                                titulo               numero  \
# 2   Publicação do Pedido de Patente ou de Certific...  BR 10 2017 004929-9
# 10  Publicação do Pedido de Patente ou de Certific...  BR 10 2018 012005-0
# 11  Publicação do Pedido de Patente ou de Certific...  BR 10 2018 012005-0
# 16  Publicação do Pedido de Patente ou de Certific...  BR 10 2018 012049-2
# 26  Publicação do Pedido de Patente ou de Certific...  BR 10 2018 012161-8
# 28  Publicação do Pedido de Patente ou de Certific...  BR 10 2018 012376-9
# 32  Publicação do Pedido de Patente ou de Certific...  BR 10 2018 012385-8
# 34  Publicação do Pedido de Patente ou de Certific...  BR 10 2018 012394-7
# 39  Publicação do Pedido de Patente ou de Certific...  BR 10 2018 012412-9
# 40  Publicação do Pedido de Patente ou de Certific...  BR 10 2018 012435-8
# 43  Publicação do Pedido de Patente ou de Certific...  BR 10 2018 012455-2
# 56  Publicação do Pedido de Patente ou de Certific...  BR 10 2018 013004-8
#
#    data_deposito data_prioridade cod_prioridade  ...  \
# 2     13/03/2017             NaN            NaN  ...
# 10    13/06/2018             NaN            NaN  ...
# 11    13/06/2018             NaN            NaN  ...
# 16    14/06/2018             NaN            NaN  ...
# 26    14/06/2018             NaN            NaN  ...
# 28    18/06/2018             NaN            NaN  ...
# 32    18/06/2018             NaN            NaN  ...
# 34    18/06/2018             NaN            NaN  ...
# 39    18/06/2018             NaN            NaN  ...
# 40    18/06/2018             NaN            NaN  ...
# 43    18/06/2018             NaN            NaN  ...
# 56    25/06/2018             NaN            NaN  ...
#
#                            classif_nacion  \
# 2                 H01Q 13/106; H01Q 1/241
# 10                              G01D 3/08
# 11                              G01D 3/08
# 16  A21D 13/045; A21D 13/047; A21D 13/066
# 26                                    NaN
# 28                                    NaN
# 32                             C01B 39/04
# 34                           G01N 29/0645
# 39  A23C 19/0765; A23L 33/135; A23L 33/21
# 40                                    NaN
# 43                C01B 33/32; C04B 12/005
# 56                  A01M 1/04; A01M 1/106
#
#                                           titulo_inid  \
# 2   UMA NOVA ANTENA DE MICROFITA TRI-BANDA, DE TAM...
# 10  METODOLOGIA PARA O MONITORAMENTO DA ESTABILIDA...
# 11  METODOLOGIA PARA O MONITORAMENTO DA ESTABILIDA...
# 16  COMPOSIÇÃO PARA ALIMENTOS SEM GLÚTEN A PARTIR ...
# 26  MICROBIOELETRODO PARA A DETECÇÃO DA BACTÉRIA A...
# 28  BIOSSENSOR ENZIMÁTICO PARA DETECÇÃO DE ORGANOF...
# 32  PROCESSO DE FABRICAÇÃO DE MATERIAIS MESOPOROSO...
# 34  MÉTODO E SISTEMA PARA INSPEÇÃO DE JUNTAS EM TU...
# 39  QUEIJO PETIT-SUISSE CAPRINO SABOR MARACUJÁ COM...
# 40  SISTEMA PARA EXTRAÇÃO DE MÁXIMA POTÊNCIA DE MÓ...
# 43  PROCESSO PARA A OBTENÇÃO DE ALUMINOSSILICATO S...
# 56  ARMADILHA LUMINOSA PARA A CAPTURA DE PEQUENOS ...
#
#                                          titular_nome  titular_uf  \
# 2                       UNIVERSIDADE FEDERAL DO CEARÁ          CE
# 10  INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNO...  PE; PE; PE
# 11  INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNO...  PE; PE; PE
# 16  INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNO...          GO
# 26                 UNIVERSIDADE FEDERAL DE UBERLÂNDIA          MG
# 28                   UNIVERSIDADE FEDERAL DO MARANHÃO          MA
# 32         UNIVERSIDADE TECNOLOGICA FEDERAL DO PARANA          PR
# 34  PETRÓLEO BRASILEIRO S.A. - PETROBRAS; UNIVERSI...      RJ; RS
# 39        UNIVERSIDADE FEDERAL DE CAMPINA GRANDE - PB          PB
# 40                 UNIVERSIDADE FEDERAL DE UBERLÂNDIA          MG
# 43               UNIVERSIDADE FEDERAL DE MINAS GERAIS          MG
# 56                   UNIVERSIDADE FEDERAL DO MARANHÃO          MA
#
#    titular_pais                                      inventor_nome  parceria  \
# 2            BR  ANTONIO SERGIO BEZERRA SOMBRA; RONALDO GLAUBER...   Titular
# 10   BR; BR; BR  JOSÉ EDUARDO FERREIRA DE OLIVEIRA; NELSON GONÇ...  Parceiro
# 11   BR; BR; BR  JOSÉ EDUARDO FERREIRA DE OLIVEIRA; NELSON GONÇ...   Titular
# 16           BR   RAFAIANE MACEDO GUIMARÃES; MARIANA BURANELO EGEA   Titular
# 26           BR  ANA GRACI BRITO MADURRO; JOÃO MARCOS MADURRO; ...   Titular
# 28           BR  ALLYSSON KAYRON DE CARVALHO SILVA; LAIANE ARAÚ...   Titular
# 32           BR  PEDRO AUGUSTO ARROYO; MURILO PEREIRA MOISÉS; E...   Titular
# 34       BR; BR  THOMAS GABRIEL ROSAURO CLARKE; SERGIO DAMASCEN...  Parceiro
# 39           BR  JANAINA SEVERO DE LIMA GAMA; MARIA ELIEIDY GOM...   Titular
# 40           BR  LUIZ CARLOS GOMES DE FREITAS; LUCAS PEREIRA PI...   Titular
# 43           BR  MARIANA ARRUDA PEREIRA; WANDER LUIZ VASCONCELO...   Titular
# 56           BR                           FRANCINALDO SOARES SILVA   Titular
#
#                                           responsavel ifes ifes_abrev
# 2                       UNIVERSIDADE FEDERAL DO CEARÁ  Sim        UFC
# 10                 UNIVERSIDADE FEDERAL DE PERNAMBUCO  Sim       UFPE
# 11  INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNO...  Sim       IFPE
# 16  INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNO...  Sim   IFGOIANO
# 26                 UNIVERSIDADE FEDERAL DE UBERLÂNDIA  Sim        UFU
# 28                   UNIVERSIDADE FEDERAL DO MARANHÃO  Sim       UFMA
# 32         UNIVERSIDADE TECNOLOGICA FEDERAL DO PARANA  Sim      UTFPR
# 34  UNIVERSIDADE FEDERAL DO RIO GRANDE DO SUL - UFRGS  Sim      UFRGS
# 39        UNIVERSIDADE FEDERAL DE CAMPINA GRANDE - PB  Sim       UFCG
# 40                 UNIVERSIDADE FEDERAL DE UBERLÂNDIA  Sim        UFU
# 43               UNIVERSIDADE FEDERAL DE MINAS GERAIS  Sim       UFMG
# 56                   UNIVERSIDADE FEDERAL DO MARANHÃO  Sim       UFMA
#
# [12 rows x 21 columns]

# %% [markdown]
# ## Exportacao em CSV e Excel

# %%
data_patentes_longo.to_csv("dados_patentes_longo_AM.csv")
data_patentes_longo.to_excel("dados_patentes_longo_AM.xlsx")
data_patentes_largo.to_csv("dados_patentes_largo_AM.csv")
data_patentes_largo.to_excel("dados_patentes_largo_AM.xlsx")
